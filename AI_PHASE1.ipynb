# %% [markdown]
# # Problem Modeling

# %% [markdown]
# #A-State Space Representation
# State Definition: Each state is represented as a position (x, y) in the 2D maze grid
#
#
# The maze grid consists of cells, where each cell can either be traversable (0) or a wall/block (-1)
#
#
# State Space Size: The state space includes all possible cell positions in the maze that are not walls

# %% [markdown]
# # B-Initial and Goal States
#
# Initial State:
# The starting position (startX, startY) of the maze
# the initial state is (0, 0)
# Goal State: The desired ending position (endX, endY)

# %% [markdown]
# # C-Actions
# Possible Actions:
# Up (dx = 0, dy = -1)
#
#
# Down (dx = 0, dy = +1)
#
#
# Left (dx = -1, dy = 0)
#
#
# Right (dx = +1, dy = 0)
#
#
# Constraints on Actions:
# Movement is restricted to traversable cells (value 0).
# Moving into cells with walls (-1) or outside the maze boundaries is prohibited

# %% [markdown]
# #D-Transition Function
# The transition function will determines how states change based on the actions
# Given a current state (x, y) and an action (dx, dy), the next state is (x + dx, y + dy), provided that this position is valid (not a wall and within maze boundaries).

# %% [markdown]
# #
# Problem Size Estimate for a 100x100 Grid:
# Maximum Size (No Walls):
# If the grid has no walls at all (every cell is traversable), the state space size would be exactly 10,000 states.
# With Some Walls :
# If we assume some cells are blocked (as walls), reducing the number of traversable states, the size will decrease accordingly.
# For example:
# 10% Walls (10% of cells blocked):
# 10,000−(10%×10,000)=9,000 states
# 10,000−(10%×10,000)=9,000 states
#
#
# 20% Walls (20% of cells blocked):
# 10,000−(20%×10,000)=8,000 states
# 10,000−(20%×10,000)=8,000  states

# %% [markdown]
# # **Modeling Assumptions:**
# 1.	**Environment representation:** The maze is a fixed-size 2D grid with defined dimensions and each cell in the grid has specific state (0 for Traversable cell) (-1 for wall cell).
# 2.	**State definition:** States are defined as grid positions (x, y) and the state space comprises all valid traversable cells in the grid.
# 3.	**Initial and Goal states:** The starting position is (startX, startY) and the goal position is (endX, endY).
# 4.	**Action Space:** Possible actions like moving up, down, left, right but we have some constraints in movement such as movement into walls (-1) or outside the grid is prohibited and actions are restricted to cells within the maze boundaries.
# 5.	**Transition function:** By giving the state points (x, y) and the action points (dx, dy) the next state will be (x + dx, y + dy).
# 6.	**Environment dynamics:** The environment is deterministic so the outcome of the action is predictable and doesn’t involve randomness.
# 7.	**Heuristics (for applicable algorithms like A*):** The Manhattan distance is used to estimate the cost to reach the goal from a given state.
# 8.	**Problem size and complexity:** The state space size depends on the number of traversable cells is a 100x100 grid with no walls has 10,000 states and walls reduce the number of states proportionally.

# %% [markdown]
# #THE SUCCESFUL RUNNING CODE

# %% [markdown]
# ###Full code

# %%
import heapq
from collections import deque
from tkinter import Tk, Canvas
import time
from memory_profiler import profile
import random
import math
from itertools import count
class Pair:
    def __init__(self, first, second, parentF, parentS, depth, costFromStart=0):
        self.first = first
        self.second = second
        self.parentF = parentF
        self.parentS = parentS
        self.depth = depth
        self.costFromStart = costFromStart

    def __lt__(self, other):
        return self.costFromStart < other.costFromStart

class Maze:
    def __init__(self, maze, startX, startY, endX, endY):
        self.maze = maze
        self.startX = startX
        self.startY = startY
        self.endX = endX
        self.endY = endY
        self.visited = [[False for _ in row] for row in maze]
        self.Xlength = len(maze)
        self.Ylength = len(maze[0])
def visualize_maze(maze):
    cell_size = 100  # Size of each cell in the maze
    window_width = maze.Ylength * cell_size
    window_height = maze.Xlength * cell_size

    # Create the tkinter window
    window = Tk()
    window.title("Maze Visualization")
    canvas = Canvas(window, width=window_width, height=window_height, bg="white")
    canvas.pack()

    # Draw the maze
    for row in range(maze.Xlength):
        for col in range(maze.Ylength):
            x1, y1 = col * cell_size, row * cell_size
            x2, y2 = x1 + cell_size, y1 + cell_size
            if maze.maze[row][col] == -1:  # Wall
                color = "black"
            elif (row, col) == (maze.startX, maze.startY):  # Start
                color = "green"
            elif (row, col) == (maze.endX, maze.endY):  # Goal
                color = "Yellow"
            else:  # Free cell
                color = "white"
            canvas.create_rectangle(x1, y1, x2, y2, fill=color, outline="gray")

    window.mainloop()

def can_move(maze, curr, direction):
    if direction == "right" and curr.first + 1 < maze.Xlength and maze.maze[curr.first + 1][curr.second] != -1:
        return True
    if direction == "left" and curr.first - 1 >= 0 and maze.maze[curr.first - 1][curr.second] != -1:
        return True
    if direction == "up" and curr.second - 1 >= 0 and maze.maze[curr.first][curr.second - 1] != -1:
        return True
    if direction == "down" and curr.second + 1 < maze.Ylength and maze.maze[curr.first][curr.second + 1] != -1:
        return True
    return False
## prints the path in the terminal and return it
def print_solution(maze, solution, curr,path=None):
    if path is None:
        path = []
    if curr.parentF == maze.startX and curr.parentS == maze.startY:
        print(f"Start: ({curr.parentF}, {curr.parentS}) moved to ({curr.first}, {curr.second}) Depth: {curr.depth}")
        path.append((curr.first, curr.second))
        return path
    else:
        print(f"Next: ({curr.parentF}, {curr.parentS}) moved to ({curr.first}, {curr.second}) Depth: {curr.depth}")
        path.append((curr.first, curr.second))

        for pair in solution:
            if pair.first == curr.parentF and pair.second == curr.parentS:
                return print_solution(maze, solution, pair,path)
    return path
# Depth-First Search
def dfs(maze):
    print("THIS IS DFS")
    stack = []  #LIFO
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth)
    stack.append(start)
    max_frontier = 1
    while stack:
        curr = stack.pop()
        solutions.append(curr)  # order of expansion
        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)  # Return the path

        if not maze.visited[curr.first][curr.second]:  #if not visisted mark it as visited
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            # Explore neighbors
            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                    stack.append(temp)
                    max_frontier = max(max_frontier, len(stack))
                    depth = max(depth, curr.depth + 1)
# Breadth-First Search
def bfs(maze):
    print("THIS IS BFS")
    queue = deque()
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth)
    queue.append(start)
    max_frontier = 1

    while queue:
        curr = queue.popleft()
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                    queue.append(temp)
                    max_frontier = max(max_frontier, len(queue))
                    depth = max(depth, curr.depth + 1)

# Greedy Best-First Search
def greedy_best_first_search(maze):
    print("THIS IS GREEDY Best-First Search")
    frontier = []
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth)
    heapq.heappush(frontier, (0, start))   #priority queue
    max_frontier = 1

    while frontier:
        _, curr = heapq.heappop(frontier)
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, solutions[-1])


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                    heuristic = abs(temp.first - maze.endX) + abs(temp.second - maze.endY)
                    heapq.heappush(frontier, (heuristic, temp))
                    max_frontier = max(max_frontier, len(frontier))
                    depth = max(depth, curr.depth + 1)

# A* Search
def a_star(maze):
    print("THIS IS A* Search")
    frontier = []
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth, 0)
    heapq.heappush(frontier, (0, start))
    max_frontier = 1

    while frontier:
        _, curr = heapq.heappop(frontier)
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    cost = curr.costFromStart + maze.maze[curr.first + dx][curr.second + dy]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1, cost)
                    heuristic = cost + abs(temp.first - maze.endX) + abs(temp.second - maze.endY)
                    heapq.heappush(frontier, (heuristic, temp))
                    max_frontier = max(max_frontier, len(frontier))
                    depth = max(depth, curr.depth + 1)

# Depth-Limited Search used in IDS
def dls(maze, curr, depth, solutions):
    if depth == 0:
        if curr.first == maze.endX and curr.second == maze.endY:
            solutions.append(curr)
            return True
        return False

    if not maze.visited[curr.first][curr.second]:
        maze.visited[curr.first][curr.second] = True
        solutions.append(curr)

        for direction in ["up", "down", "left", "right"]:
            if can_move(maze, curr, direction):
                dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                if dls(maze, temp, depth - 1, solutions):
                    return True
        solutions.pop()  # Backtrack
    return False
# Iterative Deepening Search
def ids(maze):
    print("THIS IS IDS")
    #max_depth = maze.Xlength * maze.Ylength
    max_depth=100000000
    for depth in range(max_depth):
        maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
        solutions = []
        start = Pair(maze.startX, maze.startY, -1, -1, 0)
        if dls(maze, start, depth, solutions):
            print("Found the End!")
            print(f"Max depth limit: {depth}")
            return print_solution(maze, solutions, solutions[-1])

    print("No solution found.")

# Uniform Cost Search
def uniform_cost_search(maze):
    print("THIS IS Uniform Cost Search")
    frontier = []
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth, 0)
    heapq.heappush(frontier, (0, start))
    max_frontier = 1

    while frontier:
        _, curr = heapq.heappop(frontier)
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    cost = curr.costFromStart + maze.maze[curr.first + dx][curr.second + dy]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1, cost)
                    heapq.heappush(frontier, (cost, temp))
                    max_frontier = max(max_frontier, len(frontier))
                    depth = max(depth, curr.depth + 1)

# Hill Climbing Search
def hill_climbing(maze):
    print("THIS IS Hill Climbing Search")
    solutions = []
    #path=[]
    curr = Pair(maze.startX, maze.startY, -1, -1, 0)
    solutions.append(curr)

    while True:
        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            #path.append((curr.first,curr.second))
            return print_solution(maze, solutions, curr)
        maze.visited[curr.first][curr.second] = True

        neighbors = []
        for direction in ["up", "down", "left", "right"]:
            if can_move(maze, curr, direction):
                dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                neighbor = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                if not maze.visited[neighbor.first][neighbor.second]:
                    heuristic = abs(neighbor.first - maze.endX) + abs(neighbor.second - maze.endY)
                    neighbors.append((heuristic, neighbor))

        if not neighbors:
            print("No better neighbors found, search stopped.")
            return

        # Move to the best neighbor
        neighbors.sort()  # Sort by heuristic
        _, best_neighbor = neighbors[0]

        # If the best neighbor doesn't improve, stop
        if abs(best_neighbor.first - maze.endX) + abs(best_neighbor.second - maze.endY) >= \
            abs(curr.first - maze.endX) + abs(curr.second - maze.endY):
            print("Reached a local maximum, search stopped.")
            return

        curr = best_neighbor
        solutions.append(curr)
class Individual:
    def __init__(self, maze, path=None):
        self.maze = maze
        self.path = path or self.random_path()
        self.fitness = self.calculate_fitness()

    def random_path(self):
        # Generate a random path through the maze
        path = []
        current = (self.maze.startX, self.maze.startY)
        while current != (self.maze.endX, self.maze.endY):
            possible_moves = ["up", "down", "left", "right"]
            direction = random.choice(possible_moves)
            dx, dy = {"up": (-1, 0), "down": (1, 0), "left": (0, -1), "right": (0, 1)}[direction]
            newX, newY = current[0] + dx, current[1] + dy
            if 0 <= newX < self.maze.Xlength and 0 <= newY < self.maze.Ylength and self.maze.maze[newX][newY] != -1:
                path.append(direction)
                current = (newX, newY)
        return path

    def calculate_fitness(self):
        # Fitness is inversely proportional to the path length and distance from the goal
        current = (self.maze.startX, self.maze.startY)
        distance_to_goal = abs(current[0] - self.maze.endX) + abs(current[1] - self.maze.endY)
        return len(self.path) + distance_to_goal

    def crossover(self, other):
        # Crossover by combining the first half of this individual's path with the second half of the other
        crossover_point = random.randint(1, len(self.path) - 1)
        child_path = self.path[:crossover_point] + other.path[crossover_point:]
        return Individual(self.maze, child_path)

    def mutate(self):
        # Mutate by randomly changing one move in the path
        mutation_point = random.randint(0, len(self.path) - 1)
        possible_moves = ["up", "down", "left", "right"]
        self.path[mutation_point] = random.choice(possible_moves)
        self.fitness = self.calculate_fitness()

# Genetic Algorithm Main Loop
def genetic_algorithm(maze, population_size=100, generations=1000, mutation_rate=0.01):
    population = [Individual(maze) for _ in range(population_size)]
    best_individual = None
    best_fitness = float("inf")

    for generation in range(generations):
        # Sort population by fitness (lower fitness is better)
        population.sort(key=lambda x: x.fitness)

        # Track the best solution
        if population[0].fitness < best_fitness:
            best_fitness = population[0].fitness
            best_individual = population[0]

        # Selection: Pick the top 50% individuals
        selected_individuals = population[:population_size // 2]

        # Crossover: Create new population by combining individuals
        new_population = []
        while len(new_population) < population_size:
            parent1, parent2 = random.sample(selected_individuals, 2)
            child = parent1.crossover(parent2)
            new_population.append(child)

        # Mutation: Randomly mutate some individuals
        for individual in new_population:
            if random.random() < mutation_rate:
                individual.mutate()

        population = new_population

        # Display progress
        if generation % 100 == 0:
            print(f"Generation {generation}: Best Fitness = {best_fitness}")

    # Return the best individual found
    return best_individual

@profile
def Running_DFS(maze):
    dfs(maze)

@profile
def Running_BFS(maze):
    bfs(maze)

@profile
def Running_DFS(maze):
    dfs(maze)

@profile
def Running_Greedy(maze):
    greedy_best_first_search(maze)

@profile
def Running_A_Star(maze):
    a_star(maze)

@profile
def Running_UCS(maze):
    uniform_cost_search(maze)

@profile
def Running_IDS(maze):
    return ids(maze)
@profile
def Running_Hill_Climbing(maze):
    return hill_climbing(maze)

@profile
def Running_genetic(maze):
    return genetic_algorithm(maze)

def visualize_maze_and_solution(maze, path):
    cell_size = 100  # Size of each cell in the maze
    window_width = maze.Ylength * cell_size
    window_height = maze.Xlength * cell_size

    # Create the tkinter window
    window = Tk()
    window.title("Maze Visualization")
    canvas = Canvas(window, width=window_width, height=window_height, bg="white")
    canvas.pack()

    # Draw the maze
    for row in range(maze.Xlength):
        for col in range(maze.Ylength):
            x1, y1 = col * cell_size, row * cell_size
            x2, y2 = x1 + cell_size, y1 + cell_size
            if maze.maze[row][col] == -1:  # Wall
                color = "black"
            elif (row, col) == (maze.startX, maze.startY):  # Start
                color = "green"
            elif (row, col) == (maze.endX, maze.endY):  # Goal
                color = "red"
            else:  # Normal cell
                color = "white"
            canvas.create_rectangle(x1, y1, x2, y2, fill=color, outline="gray")

    # Animate the solution path
    time.sleep(0.8)
    for step in path:
        row, col = step
        x1, y1 = col * cell_size, row * cell_size
        x2, y2 = x1 + cell_size, y1 + cell_size
        canvas.create_rectangle(x1, y1, x2, y2, fill="blue", outline="gray")
        window.update()  # Update the canvas to show the current step
        time.sleep(0.8)  # Delay

    window.mainloop()
def schedule(t):
    """Cooling schedule: Exponential decay."""
    initial_temp = 100
    cooling_rate = 0.01
    return initial_temp * math.exp(-cooling_rate * t)
def simulated_annealing(problem,schedule, verbose=False):
    """Simulated annealing search implementation."""
    current_state = (problem.startX,problem.startY)
    current_value = abs(current_state [0]- problem.endX) + abs(current_state[1] - problem.endY)
    for t in count():
        T = schedule(t)  # Temperature as a function of the step count
        if current_value == 0 or T == 0:  # Stop if goal is found or temperature is zero
            return current_state
    actions =[]
    for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    if 0 <= nx < self.maze.Xlength and 0 <= ny < self.maze.Ylength and self.maze.maze[nx][ny] != -1:
                        actions.append((dx,dy))
    next_states = [(current_state[0] + dx, current_state[1] + dy) for dx, dy in actions]
    while True:
            next_state = choice(next_states)
            next_value = abs(next_state [0]- problem.endX) + abs(next_state[1] - problem.endY)
            delta = current_value - next_value
            if delta > 0 or random.random() < exp(delta / T):  # Use random() from the random module
                current_state, current_value = next_state, next_value
                break
if __name__ == "__main__":

    # Maze layout: 0 represents a free cell, -1 represents a wall
    # Generate a 100x100 maze with random obstacles
    """  size = 100
    maze_layout = [[0 if random.random() > 0.2 else -1 for _ in range(size)] for _ in range(size)]
    print(type(maze_layout))
    # Ensure start and end points are open
    start_x, start_y = 0, 0
    end_x, end_y = size - 1, size - 1
    maze_layout[start_x][start_y] = 0
    maze_layout[end_x][end_y] = 0
    maze = Maze(maze_layout, start_x, start_y, end_x, end_y)  # Start at (0, 0), Goal at (99, 99) """
    # Maze layout: 0 represents a free cell, -1 represents a wall
    maze_layout = [
        [0, 0, 0, -1],
        [0, -1, 0, -1],
        [0, 0, 0, 0],
        [-1, 0, -1, 0]
    ]
    print(type(maze_layout))
    maze = Maze(maze_layout, 0, 0, 2, 3)  # Start at (0, 0), Goal at (2, 3)
    final_state = simulated_annealing(maze,schedule)
    print("Final state (solution):", final_state)
    '''print("\nRunning DFS:")
    start_time = time.time()
    DFS_path=Running_DFS(maze)
    end_time = time.time()
    print("Time taken = ",round((end_time - start_time),6))
    print("\nRunning BFS:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    BFS_path=Running_BFS(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning Greedy Best-First Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    Greedy_path=Running_Greedy(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning A* Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    A_star_path=Running_A_Star(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning Uniform Cost Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    UCS_path=Running_UCS(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning Hill Climbing Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    hillpath= Running_Hill_Climbing(maze)
    end_time = time.time()
    print(hillpath)
    hillpath.append((0,0)) # The solution terminates when it founds the goal without adding it
    print("Time taken = ",round(end_time - start_time,6))
    visualize_maze(maze)
    visualize_maze_and_solution(maze, hillpath)
    print("\nRunning IDS:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    IDSpath=Running_IDS(maze)
    end_time = time.time()
    visualize_maze_and_solution(maze, IDSpath)
    print("Time taken = ",round(end_time - start_time,6))
    print("BFS path",BFS_path)
    print("DFS path",DFS_path)
    print("UCS path",UCS_path)
    print("A* path",A_star_path)
    print("Greedy path",Greedy_path)
    print("IDS path",IDSpath)
    print("Hill climbing path",hillpath)

    print("\nRunning Genetic Algorithm:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    best_solution = genetic_algorithm(maze)
    end_time = time.time()
    print(f"Best path found: {best_solution.path}")
    print(f"Fitness: {best_solution.fitness}")
    print("Time taken = ",round(end_time - start_time,6))'''
    #visualize_maze(maze) # shows the initial maze only without traversing
''' Maze colors
Green -> start position (0, 0).
Red -> the goal position (2, 3).
White -> navigable.
Black -> walls.
'''
""" def run_search(maze, search_name, search_function):
        print(f"\nRunning {search_name}:")
        maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
        start_time = time.time()
        path = search_function(maze)
        end_time = time.time()
        print(f"Time taken = {round(end_time - start_time, 6)}")
        if path is not None:
            print("The path is ",path)  # print into terminal
        return path

BFS_path = run_search(maze, "BFS", Running_BFS)
DFS_path = run_search(maze, "BFS", Running_DFS)
Greedy_path = run_search(maze, "Greedy Best-First Search", Running_Greedy)
A_star_path = run_search(maze, "A* Search", Running_A_Star)
UCS_path = run_search(maze, "Uniform Cost Search", Running_UCS)
IDS_path = run_search(maze, "IDS", Running_IDS)
hillpath = run_search(maze, "Hill Climbing Search", Running_Hill_Climbing)
hillpath.append((0,0))
best_solution = run_search(maze, "Hill Climbing Search", genetic_algorithm)
print(f"Best path found: {best_solution.path}")
visualize_maze(maze)
visualize_maze_and_solution(maze, hillpath) """
# Out:
# THIS IS DFS
# Found the End!
# Nodes Expanded: 10
# Max tree depth searched: 10
# Max frontier size: 13
# Next: (4, 3) moved to (4, 4) Depth: 10
# Next: (4, 2) moved to (4, 3) Depth: 9
# Next: (3, 2) moved to (4, 2) Depth: 8
# Next: (3, 1) moved to (3, 2) Depth: 7
# Next: (4, 1) moved to (3, 1) Depth: 6
# Next: (4, 0) moved to (4, 1) Depth: 5
# Next: (3, 0) moved to (4, 0) Depth: 4
# Next: (2, 0) moved to (3, 0) Depth: 3
# Next: (1, 0) moved to (2, 0) Depth: 2
# Start: (0, 0) moved to (1, 0) Depth: 1

# %% [markdown]
# ### Divided Code

# %% [markdown]
# **Please that this code may not be running propely in colab particularly for visulaization of the maze**

# %% [markdown]
# ###imports

# %%
pip install memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in /usr/local/lib/python3.10/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from memory_profiler) (5.9.5)

# %%
import heapq
from collections import deque
from tkinter import Tk, Canvas
import time
from memory_profiler import profile
import random
import math
from itertools import count

# %%
class Pair:
    def __init__(self, first, second, parentF, parentS, depth, costFromStart=0):
        self.first = first
        self.second = second
        self.parentF = parentF
        self.parentS = parentS
        self.depth = depth
        self.costFromStart = costFromStart

    def __lt__(self, other):
        return self.costFromStart < other.costFromStart

# %%
class Maze:
  #0 represents open cells and -1 represents walls.
    def __init__(self, maze, startX, startY, endX, endY):
        self.maze = maze
        self.startX = startX
        self.startY = startY
        self.endX = endX
        self.endY = endY
        self.visited = [[False for _ in row] for row in maze]
        self.Xlength = len(maze)
        self.Ylength = len(maze[0])

    def visualize_maze(maze):
      cell_size = 100  # Size of each cell in the maze
      window_width = maze.Ylength * cell_size
      window_height = maze.Xlength * cell_size

      # Create the tkinter window
      window = Tk()
      window.title("Maze Visualization")
      canvas = Canvas(window, width=window_width, height=window_height, bg="white")
      canvas.pack()

      # Draw the maze
      for row in range(maze.Xlength):
          for col in range(maze.Ylength):
              x1, y1 = col * cell_size, row * cell_size
              x2, y2 = x1 + cell_size, y1 + cell_size
              if maze.maze[row][col] == -1:  # Wall
                  color = "black"
              elif (row, col) == (maze.startX, maze.startY):  # Start
                  color = "green"
              elif (row, col) == (maze.endX, maze.endY):  # Goal
                  color = "red"
              else:  # Free cell
                  color = "white"
              canvas.create_rectangle(x1, y1, x2, y2, fill=color, outline="gray")

      window.mainloop()

# %%
## prints the path in the terminal and return it
def print_solution(maze, solution, curr):
    path=[]
    if curr.parentF == maze.startX and curr.parentS == maze.startY:
        print(f"Start: ({curr.parentF}, {curr.parentS}) moved to ({curr.first}, {curr.second}) Depth: {curr.depth}")
        path.append((curr.first, curr.second))
        return path
    else:
        print(f"Next: ({curr.parentF}, {curr.parentS}) moved to ({curr.first}, {curr.second}) Depth: {curr.depth}")
        path.append((curr.first, curr.second))

        for pair in solution:
            if pair.first == curr.parentF and pair.second == curr.parentS:
                return print_solution(maze, solution, pair)
    return path

# %% [markdown]
# ##Visualizing code

# %%
def visualize_maze_and_solution(maze, path):
    cell_size = 100  # Size of each cell in the maze
    window_width = maze.Ylength * cell_size
    window_height = maze.Xlength * cell_size

    # Create the tkinter window
    window = Tk()
    window.title("Maze Visualization")
    canvas = Canvas(window, width=window_width, height=window_height, bg="white")
    canvas.pack()

    # Draw the maze
    for row in range(maze.Xlength):
        for col in range(maze.Ylength):
            x1, y1 = col * cell_size, row * cell_size
            x2, y2 = x1 + cell_size, y1 + cell_size
            if maze.maze[row][col] == -1:  # Wall
                color = "black"
            elif (row, col) == (maze.startX, maze.startY):  # Start
                color = "green"
            elif (row, col) == (maze.endX, maze.endY):  # Goal
                color = "red"
            else:  # Free cell
                color = "white"
            canvas.create_rectangle(x1, y1, x2, y2, fill=color, outline="gray")

    # Animate the solution path
    for step in path:
        row, col = step
        x1, y1 = col * cell_size, row * cell_size
        x2, y2 = x1 + cell_size, y1 + cell_size
        canvas.create_rectangle(x1, y1, x2, y2, fill="blue", outline="gray")
        window.update()  # Update the canvas to show the current step
        time.sleep(0.8)  # Delay for animation

    window.mainloop()

# %%
#Wall or not
def can_move(maze, curr, direction):
    if direction == "right" and curr.first + 1 < maze.Xlength and maze.maze[curr.first + 1][curr.second] != -1:
        return True
    if direction == "left" and curr.first - 1 >= 0 and maze.maze[curr.first - 1][curr.second] != -1:
        return True
    if direction == "up" and curr.second - 1 >= 0 and maze.maze[curr.first][curr.second - 1] != -1:
        return True
    if direction == "down" and curr.second + 1 < maze.Ylength and maze.maze[curr.first][curr.second + 1] != -1:
        return True
    return False

# %%
def find_min_frontier(maze, frontier):
    min_pair = min(frontier, key=lambda pair: abs(pair.first - maze.endX) + abs(pair.second - maze.endY))
    frontier.remove(min_pair)
    return min_pair

# %% [markdown]
# #Algorithms

# %% [markdown]
# ###DFS

# %%
# Depth-First Search
def dfs(maze):
    print("THIS IS DFS")
    stack = []  #LIFO
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth)
    stack.append(start)
    max_frontier = 1
    while stack:
        curr = stack.pop()
        solutions.append(curr)  # order of expansion
        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)  # Return the path

        if not maze.visited[curr.first][curr.second]:  #if not visisted mark it as visited
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            # Explore neighbors
            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                    stack.append(temp)
                    max_frontier = max(max_frontier, len(stack))
                    depth = max(depth, curr.depth + 1)

# %% [markdown]
# ###BFS

# %%
def bfs(maze):
    print("THIS IS BFS")
    queue = deque()
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth)
    queue.append(start)
    max_frontier = 1

    while queue:
        curr = queue.popleft()
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                    queue.append(temp)
                    max_frontier = max(max_frontier, len(queue))
                    depth = max(depth, curr.depth + 1)

# %% [markdown]
# ###Greedy

# %%
# Greedy Best-First Search
def greedy_best_first_search(maze):
    print("THIS IS GREEDY Best-First Search")
    frontier = []
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth)
    heapq.heappush(frontier, (0, start))   #priority queue
    max_frontier = 1

    while frontier:
        _, curr = heapq.heappop(frontier)
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, solutions[-1])


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                    heuristic = abs(temp.first - maze.endX) + abs(temp.second - maze.endY)
                    heapq.heappush(frontier, (heuristic, temp))
                    max_frontier = max(max_frontier, len(frontier))
                    depth = max(depth, curr.depth + 1)

# %% [markdown]
# ###A*

# %%
# A* Search
def a_star(maze):
    print("THIS IS A* Search")
    frontier = []
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth, 0)
    heapq.heappush(frontier, (0, start))
    max_frontier = 1

    while frontier:
        _, curr = heapq.heappop(frontier)
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    cost = curr.costFromStart + maze.maze[curr.first + dx][curr.second + dy]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1, cost)
                    heuristic = cost + abs(temp.first - maze.endX) + abs(temp.second - maze.endY)
                    heapq.heappush(frontier, (heuristic, temp))
                    max_frontier = max(max_frontier, len(frontier))
                    depth = max(depth, curr.depth + 1)

# %% [markdown]
# ###UCS

# %%
def uniform_cost_search(maze):
    print("THIS IS Uniform Cost Search")
    frontier = []
    solutions = []
    depth = 0
    max_frontier = 0
    nodes_expanded = 0

    start = Pair(maze.startX, maze.startY, -1, -1, depth, 0)
    heapq.heappush(frontier, (0, start))
    max_frontier = 1

    while frontier:
        curr_cost, curr = heapq.heappop(frontier)
        solutions.append(curr)

        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            print(f"Nodes Expanded: {nodes_expanded}")
            print(f"Max tree depth searched: {depth}")
            print(f"Max frontier size: {max_frontier}")
            return print_solution(maze, solutions, curr)


        if not maze.visited[curr.first][curr.second]:
            maze.visited[curr.first][curr.second] = True
            nodes_expanded += 1

            for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    cost = curr.costFromStart + maze.maze[curr.first + dx][curr.second + dy]
                    temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1, cost)
                    heapq.heappush(frontier, (cost, temp))
                    max_frontier = max(max_frontier, len(frontier))
                    depth = max(depth, curr.depth + 1)

# %% [markdown]
# ###IDS

# %%
# Depth-Limited Search used in IDS
def dls(maze, curr, depth, solutions):
    if depth == 0:
        if curr.first == maze.endX and curr.second == maze.endY:
            solutions.append(curr)
            return True
        return False

    if not maze.visited[curr.first][curr.second]:
        maze.visited[curr.first][curr.second] = True
        solutions.append(curr)

        for direction in ["up", "down", "left", "right"]:
            if can_move(maze, curr, direction):
                dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                if dls(maze, temp, depth - 1, solutions):
                    return True
        solutions.pop()  # Backtrack
    return False

# %%
# Iterative Deepening Search
def ids(maze):
    print("THIS IS IDS")
    #max_depth = maze.Xlength * maze.Ylength
    max_depth=100000000
    for depth in range(max_depth):
        maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
        solutions = []
        start = Pair(maze.startX, maze.startY, -1, -1, 0)
        if dls(maze, start, depth, solutions):
            print("Found the End!")
            print(f"Max depth limit: {depth}")
            return print_solution(maze, solutions, solutions[-1])

    print("No solution found.")
    return None

# %% [markdown]
# ###Hill Climbing search

# %%
# Hill Climbing Search
def hill_climbing(maze):
    print("THIS IS Hill Climbing Search")
    solutions = []
    #path=[]
    curr = Pair(maze.startX, maze.startY, -1, -1, 0)
    solutions.append(curr)

    while True:
        if curr.first == maze.endX and curr.second == maze.endY:
            print("Found the End!")
            #path.append((curr.first,curr.second))
            return print_solution(maze, solutions, curr)
        maze.visited[curr.first][curr.second] = True

        neighbors = []
        for direction in ["up", "down", "left", "right"]:
            if can_move(maze, curr, direction):
                dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                neighbor = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
                if not maze.visited[neighbor.first][neighbor.second]:
                    heuristic = abs(neighbor.first - maze.endX) + abs(neighbor.second - maze.endY)
                    neighbors.append((heuristic, neighbor))

        if not neighbors:
            print("No better neighbors found, search stopped.")
            return

# %% [markdown]
# ## Genetic

# %%
class Individual:
    def __init__(self, maze, path=None):
        self.maze = maze
        self.path = path or self.random_path()
        self.fitness = self.calculate_fitness()

    def random_path(self):
        # Generate a random path through the maze
        path = []
        current = (self.maze.startX, self.maze.startY)
        while current != (self.maze.endX, self.maze.endY):
            possible_moves = ["up", "down", "left", "right"]
            direction = random.choice(possible_moves)
            dx, dy = {"up": (-1, 0), "down": (1, 0), "left": (0, -1), "right": (0, 1)}[direction]
            newX, newY = current[0] + dx, current[1] + dy
            if 0 <= newX < self.maze.Xlength and 0 <= newY < self.maze.Ylength and self.maze.maze[newX][newY] != -1:
                path.append(direction)
                current = (newX, newY)
        return path

    def calculate_fitness(self):
        # Fitness is inversely proportional to the path length and distance from the goal
        current = (self.maze.startX, self.maze.startY)
        distance_to_goal = abs(current[0] - self.maze.endX) + abs(current[1] - self.maze.endY)
        return len(self.path) + distance_to_goal

    #other is the other child in the population to be comined with the current one
    def crossover(self, other):
        # Crossover by combining the first half of this individual's path with the second half of the other
        crossover_point = random.randint(1, len(self.path) - 1)
        child_path = self.path[:crossover_point] + other.path[crossover_point:]
        return Individual(self.maze, child_path)

    def mutate(self):
        # Mutate by randomly changing one move in the path
        mutation_point = random.randint(0, len(self.path) - 1)
        possible_moves = ["up", "down", "left", "right"]
        self.path[mutation_point] = random.choice(possible_moves)
        self.fitness = self.calculate_fitness()

# Genetic Algorithm Main Loop
def genetic_algorithm(maze, population_size=100, generations=1000, mutation_rate=0.01):
    population = [Individual(maze) for _ in range(population_size)]
    best_individual = None
    best_fitness = float("inf")

    for generation in range(generations):
        # Sort population by fitness (lower fitness is better)
        population.sort(key=lambda x: x.fitness)

        # Track the best solution
        if population[0].fitness < best_fitness:
            best_fitness = population[0].fitness
            best_individual = population[0]

        # Selection: Pick the top 50% individuals
        selected_individuals = population[:population_size // 2]

        # Crossover: Create new population by combining individuals
        new_population = []
        while len(new_population) < population_size:
            parent1, parent2 = random.sample(selected_individuals, 2)
            child = parent1.crossover(parent2)
            new_population.append(child)

        # Mutation: Randomly mutate some individuals
        for individual in new_population:
            if random.random() < mutation_rate:
                individual.mutate()

        population = new_population

        # Display progress
        if generation % 100 == 0:
            print(f"Generation {generation}: Best Fitness = {best_fitness}")

    # Return the best individual found
    return best_individual

# %% [markdown]
# ##Simulated annealing

# %%
def schedule(t):
    """Cooling schedule: Exponential decay."""
    initial_temp = 100
    cooling_rate = 0.01
    return initial_temp * math.exp(-cooling_rate * t)
def simulated_annealing(problem,schedule, verbose=False):
    """Simulated annealing search implementation."""
    current_state = (problem.startX,problem.startY)
    current_value = abs(current_state [0]- problem.endX) + abs(current_state[1] - problem.endY)
    for t in count():
        T = schedule(t)  # Temperature as a function of the step count
        if current_value == 0 or T == 0:  # Stop if goal is found or temperature is zero
            return current_state
    actions =[]
    for direction in ["up", "down", "left", "right"]:
                if can_move(maze, curr, direction):
                    dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
                    if 0 <= nx < self.maze.Xlength and 0 <= ny < self.maze.Ylength and self.maze.maze[nx][ny] != -1:
                        actions.append((dx,dy))
    next_states = [(current_state[0] + dx, current_state[1] + dy) for dx, dy in actions]
    while True:
            next_state = choice(next_states)
            next_value = abs(next_state [0]- problem.endX) + abs(next_state[1] - problem.endY)
            delta = current_value - next_value
            if delta > 0 or random.random() < exp(delta / T):  # Use random() from the random module
                current_state, current_value = next_state, next_value
                break

# %% [markdown]
# #main

# %%
@profile
def Running_DFS(maze):
    dfs(maze)

@profile
def Running_BFS(maze):
    bfs(maze)

@profile
def Running_DFS(maze):
    dfs(maze)

@profile
def Running_Greedy(maze):
    greedy_best_first_search(maze)

@profile
def Running_A_Star(maze):
    a_star(maze)

@profile
def Running_UCS(maze):
    uniform_cost_search(maze)

@profile
def Running_IDS(maze):
    return ids(maze)

@profile
def Running_Hill_Climbing(maze):
    return hill_climbing(maze)

@profile
def Running_genetic(maze):
    return genetic_algorithm(maze)

def Running_simulated_annealing(maze):
return simulated_annealing(maze,schedule)

# %% [markdown]
# ###For maze clarification

# %%
''' Maze colors
Green -> start position (0, 0).
Red -> the goal position (2, 3).
White -> navigable.
Black -> walls.
'''
# Out:
# ' Maze colors\nGreen -> start position (0, 0).\nRed -> the goal position (2, 3).\nWhite -> navigable.\nBlack -> walls.\n'

# %%
if __name__ == "__main__":

    # Maze layout: 0 represents a free cell, -1 represents a wall
    # Generate a 100x100 maze with random obstacles
    size = 100
    maze_layout = [[0 if random.random() > 0.2 else -1 for _ in range(size)] for _ in range(size)]

    # Ensure start and end points are open
    start_x, start_y = 0, 0
    end_x, end_y = size - 1, size - 1
    maze_layout[start_x][start_y] = 0
    maze_layout[end_x][end_y] = 0

    #start represents the agent's start point and end represent the goal node

    maze = Maze(maze_layout, start_x, start_y, end_x, end_y)
    print("\nRunning DFS:")
    start_time = time.time()
    DFS_path=Running_DFS(maze)
    end_time = time.time()
    print("Time taken = ",round((end_time - start_time),6))

    print("\nRunning BFS:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    BFS_path=Running_BFS(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning Greedy Best-First Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    Greedy_path=Running_Greedy(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning A* Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    A_star_path=Running_A_Star(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning Uniform Cost Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    UCS_path=Running_UCS(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))


    print("\nRunning Hill Climbing Search:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    hillpath= Running_Hill_Climbing(maze)
    print(hillpath)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))


    print("\nRunning Simulated annealing :")
    start_time = time.time()
    final_state = Running_simulated_annealing(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))
    print("Final state (solution):", final_state)

    print("\nRunning Genetic Algorithm:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    best_solution = genetic_algorithm(maze)
    end_time = time.time()
    print(f"Best path found: {best_solution.path}")
    print(f"Fitness: {best_solution.fitness}")
    print("Time taken = ",round(end_time - start_time,6))

    print("\nRunning IDS:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    IDSpath=Running_IDS(maze)
    end_time = time.time()
    print("Time taken = ",round(end_time - start_time,6))
# Out:
# Running DFS:
# ERROR: Could not find file <ipython-input-21-217c4ef642fe>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# THIS IS DFS
# Found the End!
# Nodes Expanded: 6668
# Max tree depth searched: 3239
# Max frontier size: 5650
# Next: (98, 99) moved to (99, 99) Depth: 684
# Next: (97, 99) moved to (98, 99) Depth: 683
# Next: (96, 99) moved to (97, 99) Depth: 682
# Next: (95, 99) moved to (96, 99) Depth: 681
# Next: (94, 99) moved to (95, 99) Depth: 680
# Next: (93, 99) moved to (94, 99) Depth: 679
# Next: (92, 99) moved to (93, 99) Depth: 678
# Next: (91, 99) moved to (92, 99) Depth: 677
# Next: (90, 99) moved to (91, 99) Depth: 676
# Next: (89, 99) moved to (90, 99) Depth: 675
# Next: (88, 99) moved to (89, 99) Depth: 674
# Next: (87, 99) moved to (88, 99) Depth: 673
# Next: (87, 98) moved to (87, 99) Depth: 672
# Next: (86, 98) moved to (87, 98) Depth: 671
# Next: (85, 98) moved to (86, 98) Depth: 670
# Next: (84, 98) moved to (85, 98) Depth: 669
# Next: (83, 98) moved to (84, 98) Depth: 668
# Next: (83, 99) moved to (83, 98) Depth: 667
# Next: (82, 99) moved to (83, 99) Depth: 666
# Next: (81, 99) moved to (82, 99) Depth: 665
# Next: (80, 99) moved to (81, 99) Depth: 664
# Next: (79, 99) moved to (80, 99) Depth: 663
# Next: (78, 99) moved to (79, 99) Depth: 662
# Next: (77, 99) moved to (78, 99) Depth: 661
# Next: (77, 98) moved to (77, 99) Depth: 660
# Next: (78, 98) moved to (77, 98) Depth: 659
# Next: (79, 98) moved to (78, 98) Depth: 658
# Next: (80, 98) moved to (79, 98) Depth: 657
# Next: (81, 98) moved to (80, 98) Depth: 656
# Next: (81, 97) moved to (81, 98) Depth: 655
# Next: (80, 97) moved to (81, 97) Depth: 654
# Next: (79, 97) moved to (80, 97) Depth: 653
# Next: (78, 97) moved to (79, 97) Depth: 652
# Next: (77, 97) moved to (78, 97) Depth: 651
# Next: (76, 97) moved to (77, 97) Depth: 650
# Next: (75, 97) moved to (76, 97) Depth: 649
# Next: (74, 97) moved to (75, 97) Depth: 648
# Next: (73, 97) moved to (74, 97) Depth: 647
# Next: (72, 97) moved to (73, 97) Depth: 646
# Next: (71, 97) moved to (72, 97) Depth: 645
# Next: (71, 96) moved to (71, 97) Depth: 644
# Next: (70, 96) moved to (71, 96) Depth: 643
# Next: (69, 96) moved to (70, 96) Depth: 642
# Next: (69, 95) moved to (69, 96) Depth: 641
# Next: (70, 95) moved to (69, 95) Depth: 640
# Next: (71, 95) moved to (70, 95) Depth: 639
# Next: (72, 95) moved to (71, 95) Depth: 638
# Next: (73, 95) moved to (72, 95) Depth: 637
# Next: (74, 95) moved to (73, 95) Depth: 636
# Next: (75, 95) moved to (74, 95) Depth: 635
# Next: (76, 95) moved to (75, 95) Depth: 634
# Next: (77, 95) moved to (76, 95) Depth: 633
# Next: (78, 95) moved to (77, 95) Depth: 632
# Next: (79, 95) moved to (78, 95) Depth: 631
# Next: (79, 94) moved to (79, 95) Depth: 630
# Next: (78, 94) moved to (79, 94) Depth: 629
# Next: (77, 94) moved to (78, 94) Depth: 628
# Next: (76, 94) moved to (77, 94) Depth: 627
# Next: (75, 94) moved to (76, 94) Depth: 626
# Next: (74, 94) moved to (75, 94) Depth: 625
# Next: (74, 93) moved to (74, 94) Depth: 624
# Next: (73, 93) moved to (74, 93) Depth: 623
# Next: (72, 93) moved to (73, 93) Depth: 622
# Next: (72, 92) moved to (72, 93) Depth: 621
# Next: (73, 92) moved to (72, 92) Depth: 620
# Next: (73, 91) moved to (73, 92) Depth: 619
# Next: (72, 91) moved to (73, 91) Depth: 618
# Next: (71, 91) moved to (72, 91) Depth: 617
# Next: (70, 91) moved to (71, 91) Depth: 616
# Next: (69, 91) moved to (70, 91) Depth: 615
# Next: (68, 91) moved to (69, 91) Depth: 614
# Next: (68, 90) moved to (68, 91) Depth: 613
# Next: (69, 90) moved to (68, 90) Depth: 612
# Next: (70, 90) moved to (69, 90) Depth: 611
# Next: (71, 90) moved to (70, 90) Depth: 610
# Next: (72, 90) moved to (71, 90) Depth: 609
# Next: (73, 90) moved to (72, 90) Depth: 608
# Next: (74, 90) moved to (73, 90) Depth: 607
# Next: (75, 90) moved to (74, 90) Depth: 606
# Next: (76, 90) moved to (75, 90) Depth: 605
# Next: (77, 90) moved to (76, 90) Depth: 604
# Next: (77, 91) moved to (77, 90) Depth: 603
# Next: (76, 91) moved to (77, 91) Depth: 602
# Next: (76, 92) moved to (76, 91) Depth: 601
# Next: (77, 92) moved to (76, 92) Depth: 600
# Next: (78, 92) moved to (77, 92) Depth: 599
# Next: (79, 92) moved to (78, 92) Depth: 598
# Next: (79, 91) moved to (79, 92) Depth: 597
# Next: (79, 90) moved to (79, 91) Depth: 596
# Next: (80, 90) moved to (79, 90) Depth: 595
# Next: (81, 90) moved to (80, 90) Depth: 594
# Next: (82, 90) moved to (81, 90) Depth: 593
# Next: (83, 90) moved to (82, 90) Depth: 592
# Next: (84, 90) moved to (83, 90) Depth: 591
# Next: (85, 90) moved to (84, 90) Depth: 590
# Next: (85, 89) moved to (85, 90) Depth: 589
# Next: (84, 89) moved to (85, 89) Depth: 588
# Next: (84, 88) moved to (84, 89) Depth: 587
# Next: (83, 88) moved to (84, 88) Depth: 586
# Next: (83, 87) moved to (83, 88) Depth: 585
# Next: (84, 87) moved to (83, 87) Depth: 584
# Next: (84, 86) moved to (84, 87) Depth: 583
# Next: (83, 86) moved to (84, 86) Depth: 582
# Next: (83, 85) moved to (83, 86) Depth: 581
# Next: (84, 85) moved to (83, 85) Depth: 580
# Next: (85, 85) moved to (84, 85) Depth: 579
# Next: (86, 85) moved to (85, 85) Depth: 578
# Next: (86, 86) moved to (86, 85) Depth: 577
# Next: (86, 87) moved to (86, 86) Depth: 576
# Next: (86, 88) moved to (86, 87) Depth: 575
# Next: (87, 88) moved to (86, 88) Depth: 574
# Next: (88, 88) moved to (87, 88) Depth: 573
# Next: (89, 88) moved to (88, 88) Depth: 572
# Next: (89, 89) moved to (89, 88) Depth: 571
# Next: (90, 89) moved to (89, 89) Depth: 570
# Next: (90, 90) moved to (90, 89) Depth: 569
# Next: (91, 90) moved to (90, 90) Depth: 568
# Next: (92, 90) moved to (91, 90) Depth: 567
# Next: (93, 90) moved to (92, 90) Depth: 566
# Next: (94, 90) moved to (93, 90) Depth: 565
# Next: (95, 90) moved to (94, 90) Depth: 564
# Next: (95, 89) moved to (95, 90) Depth: 563
# Next: (96, 89) moved to (95, 89) Depth: 562
# Next: (97, 89) moved to (96, 89) Depth: 561
# Next: (98, 89) moved to (97, 89) Depth: 560
# Next: (99, 89) moved to (98, 89) Depth: 559
# Next: (99, 88) moved to (99, 89) Depth: 558
# Next: (98, 88) moved to (99, 88) Depth: 557
# Next: (97, 88) moved to (98, 88) Depth: 556
# Next: (96, 88) moved to (97, 88) Depth: 555
# Next: (95, 88) moved to (96, 88) Depth: 554
# Next: (94, 88) moved to (95, 88) Depth: 553
# Next: (93, 88) moved to (94, 88) Depth: 552
# Next: (92, 88) moved to (93, 88) Depth: 551
# Next: (92, 87) moved to (92, 88) Depth: 550
# Next: (93, 87) moved to (92, 87) Depth: 549
# Next: (94, 87) moved to (93, 87) Depth: 548
# Next: (95, 87) moved to (94, 87) Depth: 547
# Next: (96, 87) moved to (95, 87) Depth: 546
# Next: (97, 87) moved to (96, 87) Depth: 545
# Next: (98, 87) moved to (97, 87) Depth: 544
# Next: (99, 87) moved to (98, 87) Depth: 543
# Next: (99, 86) moved to (99, 87) Depth: 542
# Next: (98, 86) moved to (99, 86) Depth: 541
# Next: (97, 86) moved to (98, 86) Depth: 540
# Next: (96, 86) moved to (97, 86) Depth: 539
# Next: (96, 85) moved to (96, 86) Depth: 538
# Next: (95, 85) moved to (96, 85) Depth: 537
# Next: (94, 85) moved to (95, 85) Depth: 536
# Next: (93, 85) moved to (94, 85) Depth: 535
# Next: (92, 85) moved to (93, 85) Depth: 534
# Next: (91, 85) moved to (92, 85) Depth: 533
# Next: (91, 84) moved to (91, 85) Depth: 532
# Next: (90, 84) moved to (91, 84) Depth: 531
# Next: (89, 84) moved to (90, 84) Depth: 530
# Next: (88, 84) moved to (89, 84) Depth: 529
# Next: (88, 83) moved to (88, 84) Depth: 528
# Next: (87, 83) moved to (88, 83) Depth: 527
# Next: (87, 82) moved to (87, 83) Depth: 526
# Next: (86, 82) moved to (87, 82) Depth: 525
# Next: (85, 82) moved to (86, 82) Depth: 524
# Next: (84, 82) moved to (85, 82) Depth: 523
# Next: (83, 82) moved to (84, 82) Depth: 522
# Next: (83, 81) moved to (83, 82) Depth: 521
# Next: (82, 81) moved to (83, 81) Depth: 520
# Next: (81, 81) moved to (82, 81) Depth: 519
# Next: (80, 81) moved to (81, 81) Depth: 518
# Next: (79, 81) moved to (80, 81) Depth: 517
# Next: (78, 81) moved to (79, 81) Depth: 516
# Next: (77, 81) moved to (78, 81) Depth: 515
# Next: (76, 81) moved to (77, 81) Depth: 514
# Next: (76, 80) moved to (76, 81) Depth: 513
# Next: (75, 80) moved to (76, 80) Depth: 512
# Next: (74, 80) moved to (75, 80) Depth: 511
# Next: (73, 80) moved to (74, 80) Depth: 510
# Next: (72, 80) moved to (73, 80) Depth: 509
# Next: (71, 80) moved to (72, 80) Depth: 508
# Next: (70, 80) moved to (71, 80) Depth: 507
# Next: (69, 80) moved to (70, 80) Depth: 506
# Next: (68, 80) moved to (69, 80) Depth: 505
# Next: (67, 80) moved to (68, 80) Depth: 504
# Next: (66, 80) moved to (67, 80) Depth: 503
# Next: (65, 80) moved to (66, 80) Depth: 502
# Next: (64, 80) moved to (65, 80) Depth: 501
# Next: (63, 80) moved to (64, 80) Depth: 500
# Next: (62, 80) moved to (63, 80) Depth: 499
# Next: (61, 80) moved to (62, 80) Depth: 498
# Next: (61, 79) moved to (61, 80) Depth: 497
# Next: (62, 79) moved to (61, 79) Depth: 496
# Next: (63, 79) moved to (62, 79) Depth: 495
# Next: (64, 79) moved to (63, 79) Depth: 494
# Next: (65, 79) moved to (64, 79) Depth: 493
# Next: (66, 79) moved to (65, 79) Depth: 492
# Next: (67, 79) moved to (66, 79) Depth: 491
# Next: (68, 79) moved to (67, 79) Depth: 490
# Next: (69, 79) moved to (68, 79) Depth: 489
# Next: (70, 79) moved to (69, 79) Depth: 488
# Next: (71, 79) moved to (70, 79) Depth: 487
# Next: (72, 79) moved to (71, 79) Depth: 486
# Next: (72, 78) moved to (72, 79) Depth: 485
# Next: (73, 78) moved to (72, 78) Depth: 484
# Next: (74, 78) moved to (73, 78) Depth: 483
# Next: (74, 77) moved to (74, 78) Depth: 482
# Next: (73, 77) moved to (74, 77) Depth: 481
# Next: (72, 77) moved to (73, 77) Depth: 480
# Next: (72, 76) moved to (72, 77) Depth: 479
# Next: (71, 76) moved to (72, 76) Depth: 478
# Next: (71, 75) moved to (71, 76) Depth: 477
# Next: (72, 75) moved to (71, 75) Depth: 476
# Next: (73, 75) moved to (72, 75) Depth: 475
# Next: (74, 75) moved to (73, 75) Depth: 474
# Next: (75, 75) moved to (74, 75) Depth: 473
# Next: (76, 75) moved to (75, 75) Depth: 472
# Next: (77, 75) moved to (76, 75) Depth: 471
# Next: (78, 75) moved to (77, 75) Depth: 470
# Next: (78, 74) moved to (78, 75) Depth: 469
# Next: (79, 74) moved to (78, 74) Depth: 468
# Next: (80, 74) moved to (79, 74) Depth: 467
# Next: (81, 74) moved to (80, 74) Depth: 466
# Next: (82, 74) moved to (81, 74) Depth: 465
# Next: (83, 74) moved to (82, 74) Depth: 464
# Next: (84, 74) moved to (83, 74) Depth: 463
# Next: (85, 74) moved to (84, 74) Depth: 462
# Next: (86, 74) moved to (85, 74) Depth: 461
# Next: (86, 73) moved to (86, 74) Depth: 460
# Next: (85, 73) moved to (86, 73) Depth: 459
# Next: (84, 73) moved to (85, 73) Depth: 458
# Next: (83, 73) moved to (84, 73) Depth: 457
# Next: (82, 73) moved to (83, 73) Depth: 456
# Next: (81, 73) moved to (82, 73) Depth: 455
# Next: (80, 73) moved to (81, 73) Depth: 454
# Next: (79, 73) moved to (80, 73) Depth: 453
# Next: (78, 73) moved to (79, 73) Depth: 452
# Next: (77, 73) moved to (78, 73) Depth: 451
# Next: (76, 73) moved to (77, 73) Depth: 450
# Next: (75, 73) moved to (76, 73) Depth: 449
# Next: (74, 73) moved to (75, 73) Depth: 448
# Next: (73, 73) moved to (74, 73) Depth: 447
# Next: (72, 73) moved to (73, 73) Depth: 446
# Next: (71, 73) moved to (72, 73) Depth: 445
# Next: (70, 73) moved to (71, 73) Depth: 444
# Next: (70, 72) moved to (70, 73) Depth: 443
# Next: (69, 72) moved to (70, 72) Depth: 442
# Next: (68, 72) moved to (69, 72) Depth: 441
# Next: (68, 71) moved to (68, 72) Depth: 440
# Next: (69, 71) moved to (68, 71) Depth: 439
# Next: (70, 71) moved to (69, 71) Depth: 438
# Next: (71, 71) moved to (70, 71) Depth: 437
# Next: (72, 71) moved to (71, 71) Depth: 436
# Next: (73, 71) moved to (72, 71) Depth: 435
# Next: (73, 70) moved to (73, 71) Depth: 434
# Next: (72, 70) moved to (73, 70) Depth: 433
# Next: (71, 70) moved to (72, 70) Depth: 432
# Next: (70, 70) moved to (71, 70) Depth: 431
# Next: (69, 70) moved to (70, 70) Depth: 430
# Next: (68, 70) moved to (69, 70) Depth: 429
# Next: (67, 70) moved to (68, 70) Depth: 428
# Next: (66, 70) moved to (67, 70) Depth: 427
# Next: (66, 69) moved to (66, 70) Depth: 426
# Next: (67, 69) moved to (66, 69) Depth: 425
# Next: (68, 69) moved to (67, 69) Depth: 424
# Next: (69, 69) moved to (68, 69) Depth: 423
# Next: (70, 69) moved to (69, 69) Depth: 422
# Next: (71, 69) moved to (70, 69) Depth: 421
# Next: (72, 69) moved to (71, 69) Depth: 420
# Next: (73, 69) moved to (72, 69) Depth: 419
# Next: (74, 69) moved to (73, 69) Depth: 418
# Next: (75, 69) moved to (74, 69) Depth: 417
# Next: (76, 69) moved to (75, 69) Depth: 416
# Next: (77, 69) moved to (76, 69) Depth: 415
# Next: (78, 69) moved to (77, 69) Depth: 414
# Next: (79, 69) moved to (78, 69) Depth: 413
# Next: (80, 69) moved to (79, 69) Depth: 412
# Next: (81, 69) moved to (80, 69) Depth: 411
# Next: (82, 69) moved to (81, 69) Depth: 410
# Next: (83, 69) moved to (82, 69) Depth: 409
# Next: (84, 69) moved to (83, 69) Depth: 408
# Next: (85, 69) moved to (84, 69) Depth: 407
# Next: (86, 69) moved to (85, 69) Depth: 406
# Next: (87, 69) moved to (86, 69) Depth: 405
# Next: (88, 69) moved to (87, 69) Depth: 404
# Next: (88, 68) moved to (88, 69) Depth: 403
# Next: (89, 68) moved to (88, 68) Depth: 402
# Next: (90, 68) moved to (89, 68) Depth: 401
# Next: (91, 68) moved to (90, 68) Depth: 400
# Next: (91, 67) moved to (91, 68) Depth: 399
# Next: (92, 67) moved to (91, 67) Depth: 398
# Next: (93, 67) moved to (92, 67) Depth: 397
# Next: (94, 67) moved to (93, 67) Depth: 396
# Next: (95, 67) moved to (94, 67) Depth: 395
# Next: (96, 67) moved to (95, 67) Depth: 394
# Next: (97, 67) moved to (96, 67) Depth: 393
# Next: (98, 67) moved to (97, 67) Depth: 392
# Next: (99, 67) moved to (98, 67) Depth: 391
# Next: (99, 66) moved to (99, 67) Depth: 390
# Next: (99, 65) moved to (99, 66) Depth: 389
# Next: (98, 65) moved to (99, 65) Depth: 388
# Next: (97, 65) moved to (98, 65) Depth: 387
# Next: (96, 65) moved to (97, 65) Depth: 386
# Next: (95, 65) moved to (96, 65) Depth: 385
# Next: (95, 64) moved to (95, 65) Depth: 384
# Next: (94, 64) moved to (95, 64) Depth: 383
# Next: (94, 63) moved to (94, 64) Depth: 382
# Next: (95, 63) moved to (94, 63) Depth: 381
# Next: (96, 63) moved to (95, 63) Depth: 380
# Next: (97, 63) moved to (96, 63) Depth: 379
# Next: (98, 63) moved to (97, 63) Depth: 378
# Next: (99, 63) moved to (98, 63) Depth: 377
# Next: (99, 62) moved to (99, 63) Depth: 376
# Next: (98, 62) moved to (99, 62) Depth: 375
# Next: (98, 61) moved to (98, 62) Depth: 374
# Next: (97, 61) moved to (98, 61) Depth: 373
# Next: (96, 61) moved to (97, 61) Depth: 372
# Next: (95, 61) moved to (96, 61) Depth: 371
# Next: (95, 60) moved to (95, 61) Depth: 370
# Next: (96, 60) moved to (95, 60) Depth: 369
# Next: (97, 60) moved to (96, 60) Depth: 368
# Next: (98, 60) moved to (97, 60) Depth: 367
# Next: (99, 60) moved to (98, 60) Depth: 366
# Next: (99, 59) moved to (99, 60) Depth: 365
# Next: (98, 59) moved to (99, 59) Depth: 364
# Next: (97, 59) moved to (98, 59) Depth: 363
# Next: (96, 59) moved to (97, 59) Depth: 362
# Next: (95, 59) moved to (96, 59) Depth: 361
# Next: (95, 58) moved to (95, 59) Depth: 360
# Next: (94, 58) moved to (95, 58) Depth: 359
# Next: (93, 58) moved to (94, 58) Depth: 358
# Next: (92, 58) moved to (93, 58) Depth: 357
# Next: (91, 58) moved to (92, 58) Depth: 356
# Next: (90, 58) moved to (91, 58) Depth: 355
# Next: (89, 58) moved to (90, 58) Depth: 354
# Next: (88, 58) moved to (89, 58) Depth: 353
# Next: (87, 58) moved to (88, 58) Depth: 352
# Next: (86, 58) moved to (87, 58) Depth: 351
# Next: (85, 58) moved to (86, 58) Depth: 350
# Next: (85, 57) moved to (85, 58) Depth: 349
# Next: (86, 57) moved to (85, 57) Depth: 348
# Next: (87, 57) moved to (86, 57) Depth: 347
# Next: (88, 57) moved to (87, 57) Depth: 346
# Next: (89, 57) moved to (88, 57) Depth: 345
# Next: (90, 57) moved to (89, 57) Depth: 344
# Next: (91, 57) moved to (90, 57) Depth: 343
# Next: (91, 56) moved to (91, 57) Depth: 342
# Next: (90, 56) moved to (91, 56) Depth: 341
# Next: (89, 56) moved to (90, 56) Depth: 340
# Next: (88, 56) moved to (89, 56) Depth: 339
# Next: (87, 56) moved to (88, 56) Depth: 338
# Next: (86, 56) moved to (87, 56) Depth: 337
# Next: (85, 56) moved to (86, 56) Depth: 336
# Next: (85, 55) moved to (85, 56) Depth: 335
# Next: (86, 55) moved to (85, 55) Depth: 334
# Next: (87, 55) moved to (86, 55) Depth: 333
# Next: (88, 55) moved to (87, 55) Depth: 332
# Next: (89, 55) moved to (88, 55) Depth: 331
# Next: (90, 55) moved to (89, 55) Depth: 330
# Next: (91, 55) moved to (90, 55) Depth: 329
# Next: (92, 55) moved to (91, 55) Depth: 328
# Next: (92, 54) moved to (92, 55) Depth: 327
# Next: (93, 54) moved to (92, 54) Depth: 326
# Next: (94, 54) moved to (93, 54) Depth: 325
# Next: (95, 54) moved to (94, 54) Depth: 324
# Next: (96, 54) moved to (95, 54) Depth: 323
# Next: (96, 55) moved to (96, 54) Depth: 322
# Next: (97, 55) moved to (96, 55) Depth: 321
# Next: (98, 55) moved to (97, 55) Depth: 320
# Next: (99, 55) moved to (98, 55) Depth: 319
# Next: (99, 54) moved to (99, 55) Depth: 318
# Next: (99, 53) moved to (99, 54) Depth: 317
# Next: (99, 52) moved to (99, 53) Depth: 316
# Next: (99, 51) moved to (99, 52) Depth: 315
# Next: (99, 50) moved to (99, 51) Depth: 314
# Next: (98, 50) moved to (99, 50) Depth: 313
# Next: (97, 50) moved to (98, 50) Depth: 312
# Next: (96, 50) moved to (97, 50) Depth: 311
# Next: (95, 50) moved to (96, 50) Depth: 310
# Next: (94, 50) moved to (95, 50) Depth: 309
# Next: (94, 49) moved to (94, 50) Depth: 308
# Next: (95, 49) moved to (94, 49) Depth: 307
# Next: (96, 49) moved to (95, 49) Depth: 306
# Next: (97, 49) moved to (96, 49) Depth: 305
# Next: (97, 48) moved to (97, 49) Depth: 304
# Next: (98, 48) moved to (97, 48) Depth: 303
# Next: (98, 47) moved to (98, 48) Depth: 302
# Next: (98, 46) moved to (98, 47) Depth: 301
# Next: (99, 46) moved to (98, 46) Depth: 300
# Next: (99, 45) moved to (99, 46) Depth: 299
# Next: (98, 45) moved to (99, 45) Depth: 298
# Next: (97, 45) moved to (98, 45) Depth: 297
# Next: (96, 45) moved to (97, 45) Depth: 296
# Next: (96, 46) moved to (96, 45) Depth: 295
# Next: (95, 46) moved to (96, 46) Depth: 294
# Next: (94, 46) moved to (95, 46) Depth: 293
# Next: (93, 46) moved to (94, 46) Depth: 292
# Next: (92, 46) moved to (93, 46) Depth: 291
# Next: (91, 46) moved to (92, 46) Depth: 290
# Next: (91, 45) moved to (91, 46) Depth: 289
# Next: (90, 45) moved to (91, 45) Depth: 288
# Next: (90, 44) moved to (90, 45) Depth: 287
# Next: (91, 44) moved to (90, 44) Depth: 286
# Next: (92, 44) moved to (91, 44) Depth: 285
# Next: (93, 44) moved to (92, 44) Depth: 284
# Next: (94, 44) moved to (93, 44) Depth: 283
# Next: (95, 44) moved to (94, 44) Depth: 282
# Next: (96, 44) moved to (95, 44) Depth: 281
# Next: (97, 44) moved to (96, 44) Depth: 280
# Next: (98, 44) moved to (97, 44) Depth: 279
# Next: (99, 44) moved to (98, 44) Depth: 278
# Next: (99, 43) moved to (99, 44) Depth: 277
# Next: (98, 43) moved to (99, 43) Depth: 276
# Next: (97, 43) moved to (98, 43) Depth: 275
# Next: (96, 43) moved to (97, 43) Depth: 274
# Next: (95, 43) moved to (96, 43) Depth: 273
# Next: (94, 43) moved to (95, 43) Depth: 272
# Next: (94, 42) moved to (94, 43) Depth: 271
# Next: (93, 42) moved to (94, 42) Depth: 270
# Next: (93, 41) moved to (93, 42) Depth: 269
# Next: (92, 41) moved to (93, 41) Depth: 268
# Next: (92, 40) moved to (92, 41) Depth: 267
# Next: (91, 40) moved to (92, 40) Depth: 266
# Next: (91, 39) moved to (91, 40) Depth: 265
# Next: (92, 39) moved to (91, 39) Depth: 264
# Next: (93, 39) moved to (92, 39) Depth: 263
# Next: (94, 39) moved to (93, 39) Depth: 262
# Next: (95, 39) moved to (94, 39) Depth: 261
# Next: (96, 39) moved to (95, 39) Depth: 260
# Next: (97, 39) moved to (96, 39) Depth: 259
# Next: (98, 39) moved to (97, 39) Depth: 258
# Next: (99, 39) moved to (98, 39) Depth: 257
# Next: (99, 38) moved to (99, 39) Depth: 256
# Next: (98, 38) moved to (99, 38) Depth: 255
# Next: (97, 38) moved to (98, 38) Depth: 254
# Next: (96, 38) moved to (97, 38) Depth: 253
# Next: (95, 38) moved to (96, 38) Depth: 252
# Next: (95, 37) moved to (95, 38) Depth: 251
# Next: (94, 37) moved to (95, 37) Depth: 250
# Next: (93, 37) moved to (94, 37) Depth: 249
# Next: (93, 36) moved to (93, 37) Depth: 248
# Next: (94, 36) moved to (93, 36) Depth: 247
# Next: (95, 36) moved to (94, 36) Depth: 246
# Next: (95, 35) moved to (95, 36) Depth: 245
# Next: (94, 35) moved to (95, 35) Depth: 244
# Next: (93, 35) moved to (94, 35) Depth: 243
# Next: (92, 35) moved to (93, 35) Depth: 242
# Next: (91, 35) moved to (92, 35) Depth: 241
# Next: (90, 35) moved to (91, 35) Depth: 240
# Next: (89, 35) moved to (90, 35) Depth: 239
# Next: (89, 34) moved to (89, 35) Depth: 238
# Next: (90, 34) moved to (89, 34) Depth: 237
# Next: (91, 34) moved to (90, 34) Depth: 236
# Next: (91, 33) moved to (91, 34) Depth: 235
# Next: (91, 32) moved to (91, 33) Depth: 234
# Next: (92, 32) moved to (91, 32) Depth: 233
# Next: (93, 32) moved to (92, 32) Depth: 232
# Next: (94, 32) moved to (93, 32) Depth: 231
# Next: (95, 32) moved to (94, 32) Depth: 230
# Next: (96, 32) moved to (95, 32) Depth: 229
# Next: (97, 32) moved to (96, 32) Depth: 228
# Next: (98, 32) moved to (97, 32) Depth: 227
# Next: (99, 32) moved to (98, 32) Depth: 226
# Next: (99, 31) moved to (99, 32) Depth: 225
# Next: (98, 31) moved to (99, 31) Depth: 224
# Next: (98, 30) moved to (98, 31) Depth: 223
# Next: (99, 30) moved to (98, 30) Depth: 222
# Next: (99, 29) moved to (99, 30) Depth: 221
# Next: (98, 29) moved to (99, 29) Depth: 220
# Next: (98, 28) moved to (98, 29) Depth: 219
# Next: (97, 28) moved to (98, 28) Depth: 218
# Next: (96, 28) moved to (97, 28) Depth: 217
# Next: (95, 28) moved to (96, 28) Depth: 216
# Next: (94, 28) moved to (95, 28) Depth: 215
# Next: (93, 28) moved to (94, 28) Depth: 214
# Next: (92, 28) moved to (93, 28) Depth: 213
# Next: (91, 28) moved to (92, 28) Depth: 212
# Next: (91, 27) moved to (91, 28) Depth: 211
# Next: (90, 27) moved to (91, 27) Depth: 210
# Next: (90, 26) moved to (90, 27) Depth: 209
# Next: (89, 26) moved to (90, 26) Depth: 208
# Next: (88, 26) moved to (89, 26) Depth: 207
# Next: (87, 26) moved to (88, 26) Depth: 206
# Next: (86, 26) moved to (87, 26) Depth: 205
# Next: (86, 25) moved to (86, 26) Depth: 204
# Next: (85, 25) moved to (86, 25) Depth: 203
# Next: (84, 25) moved to (85, 25) Depth: 202
# Next: (83, 25) moved to (84, 25) Depth: 201
# Next: (82, 25) moved to (83, 25) Depth: 200
# Next: (81, 25) moved to (82, 25) Depth: 199
# Next: (81, 24) moved to (81, 25) Depth: 198
# Next: (80, 24) moved to (81, 24) Depth: 197
# Next: (80, 23) moved to (80, 24) Depth: 196
# Next: (81, 23) moved to (80, 23) Depth: 195
# Next: (82, 23) moved to (81, 23) Depth: 194
# Next: (83, 23) moved to (82, 23) Depth: 193
# Next: (84, 23) moved to (83, 23) Depth: 192
# Next: (85, 23) moved to (84, 23) Depth: 191
# Next: (86, 23) moved to (85, 23) Depth: 190
# Next: (86, 22) moved to (86, 23) Depth: 189
# Next: (85, 22) moved to (86, 22) Depth: 188
# Next: (85, 21) moved to (85, 22) Depth: 187
# Next: (86, 21) moved to (85, 21) Depth: 186
# Next: (86, 20) moved to (86, 21) Depth: 185
# Next: (86, 19) moved to (86, 20) Depth: 184
# Next: (85, 19) moved to (86, 19) Depth: 183
# Next: (84, 19) moved to (85, 19) Depth: 182
# Next: (84, 20) moved to (84, 19) Depth: 181
# Next: (83, 20) moved to (84, 20) Depth: 180
# Next: (82, 20) moved to (83, 20) Depth: 179
# Next: (82, 19) moved to (82, 20) Depth: 178
# Next: (81, 19) moved to (82, 19) Depth: 177
# Next: (81, 18) moved to (81, 19) Depth: 176
# Next: (82, 18) moved to (81, 18) Depth: 175
# Next: (83, 18) moved to (82, 18) Depth: 174
# Next: (84, 18) moved to (83, 18) Depth: 173
# Next: (84, 17) moved to (84, 18) Depth: 172
# Next: (83, 17) moved to (84, 17) Depth: 171
# Next: (83, 16) moved to (83, 17) Depth: 170
# Next: (82, 16) moved to (83, 16) Depth: 169
# Next: (82, 15) moved to (82, 16) Depth: 168
# Next: (83, 15) moved to (82, 15) Depth: 167
# Next: (84, 15) moved to (83, 15) Depth: 166
# Next: (85, 15) moved to (84, 15) Depth: 165
# Next: (86, 15) moved to (85, 15) Depth: 164
# Next: (87, 15) moved to (86, 15) Depth: 163
# Next: (88, 15) moved to (87, 15) Depth: 162
# Next: (89, 15) moved to (88, 15) Depth: 161
# Next: (90, 15) moved to (89, 15) Depth: 160
# Next: (91, 15) moved to (90, 15) Depth: 159
# Next: (92, 15) moved to (91, 15) Depth: 158
# Next: (93, 15) moved to (92, 15) Depth: 157
# Next: (93, 16) moved to (93, 15) Depth: 156
# Next: (92, 16) moved to (93, 16) Depth: 155
# Next: (92, 17) moved to (92, 16) Depth: 154
# Next: (93, 17) moved to (92, 17) Depth: 153
# Next: (94, 17) moved to (93, 17) Depth: 152
# Next: (95, 17) moved to (94, 17) Depth: 151
# Next: (96, 17) moved to (95, 17) Depth: 150
# Next: (97, 17) moved to (96, 17) Depth: 149
# Next: (97, 16) moved to (97, 17) Depth: 148
# Next: (98, 16) moved to (97, 16) Depth: 147
# Next: (99, 16) moved to (98, 16) Depth: 146
# Next: (99, 15) moved to (99, 16) Depth: 145
# Next: (98, 15) moved to (99, 15) Depth: 144
# Next: (97, 15) moved to (98, 15) Depth: 143
# Next: (96, 15) moved to (97, 15) Depth: 142
# Next: (95, 15) moved to (96, 15) Depth: 141
# Next: (94, 15) moved to (95, 15) Depth: 140
# Next: (94, 14) moved to (94, 15) Depth: 139
# Next: (93, 14) moved to (94, 14) Depth: 138
# Next: (92, 14) moved to (93, 14) Depth: 137
# Next: (91, 14) moved to (92, 14) Depth: 136
# Next: (90, 14) moved to (91, 14) Depth: 135
# Next: (89, 14) moved to (90, 14) Depth: 134
# Next: (88, 14) moved to (89, 14) Depth: 133
# Next: (87, 14) moved to (88, 14) Depth: 132
# Next: (87, 13) moved to (87, 14) Depth: 131
# Next: (86, 13) moved to (87, 13) Depth: 130
# Next: (85, 13) moved to (86, 13) Depth: 129
# Next: (84, 13) moved to (85, 13) Depth: 128
# Next: (83, 13) moved to (84, 13) Depth: 127
# Next: (82, 13) moved to (83, 13) Depth: 126
# Next: (82, 12) moved to (82, 13) Depth: 125
# Next: (81, 12) moved to (82, 12) Depth: 124
# Next: (80, 12) moved to (81, 12) Depth: 123
# Next: (80, 11) moved to (80, 12) Depth: 122
# Next: (79, 11) moved to (80, 11) Depth: 121
# Next: (78, 11) moved to (79, 11) Depth: 120
# Next: (77, 11) moved to (78, 11) Depth: 119
# Next: (76, 11) moved to (77, 11) Depth: 118
# Next: (75, 11) moved to (76, 11) Depth: 117
# Next: (74, 11) moved to (75, 11) Depth: 116
# Next: (74, 10) moved to (74, 11) Depth: 115
# Next: (73, 10) moved to (74, 10) Depth: 114
# Next: (72, 10) moved to (73, 10) Depth: 113
# Next: (71, 10) moved to (72, 10) Depth: 112
# Next: (71, 11) moved to (71, 10) Depth: 111
# Next: (70, 11) moved to (71, 11) Depth: 110
# Next: (69, 11) moved to (70, 11) Depth: 109
# Next: (68, 11) moved to (69, 11) Depth: 108
# Next: (67, 11) moved to (68, 11) Depth: 107
# Next: (66, 11) moved to (67, 11) Depth: 106
# Next: (65, 11) moved to (66, 11) Depth: 105
# Next: (64, 11) moved to (65, 11) Depth: 104
# Next: (64, 12) moved to (64, 11) Depth: 103
# Next: (63, 12) moved to (64, 12) Depth: 102
# Next: (62, 12) moved to (63, 12) Depth: 101
# Next: (61, 12) moved to (62, 12) Depth: 100
# Next: (60, 12) moved to (61, 12) Depth: 99
# Next: (59, 12) moved to (60, 12) Depth: 98
# Next: (58, 12) moved to (59, 12) Depth: 97
# Next: (58, 13) moved to (58, 12) Depth: 96
# Next: (57, 13) moved to (58, 13) Depth: 95
# Next: (56, 13) moved to (57, 13) Depth: 94
# Next: (55, 13) moved to (56, 13) Depth: 93
# Next: (54, 13) moved to (55, 13) Depth: 92
# Next: (53, 13) moved to (54, 13) Depth: 91
# Next: (52, 13) moved to (53, 13) Depth: 90
# Next: (51, 13) moved to (52, 13) Depth: 89
# Next: (50, 13) moved to (51, 13) Depth: 88
# Next: (49, 13) moved to (50, 13) Depth: 87
# Next: (48, 13) moved to (49, 13) Depth: 86
# Next: (47, 13) moved to (48, 13) Depth: 85
# Next: (46, 13) moved to (47, 13) Depth: 84
# Next: (45, 13) moved to (46, 13) Depth: 83
# Next: (44, 13) moved to (45, 13) Depth: 82
# Next: (43, 13) moved to (44, 13) Depth: 81
# Next: (42, 13) moved to (43, 13) Depth: 80
# Next: (41, 13) moved to (42, 13) Depth: 79
# Next: (40, 13) moved to (41, 13) Depth: 78
# Next: (39, 13) moved to (40, 13) Depth: 77
# Next: (39, 12) moved to (39, 13) Depth: 76
# Next: (38, 12) moved to (39, 12) Depth: 75
# Next: (38, 11) moved to (38, 12) Depth: 74
# Next: (37, 11) moved to (38, 11) Depth: 73
# Next: (36, 11) moved to (37, 11) Depth: 72
# Next: (36, 10) moved to (36, 11) Depth: 71
# Next: (35, 10) moved to (36, 10) Depth: 70
# Next: (34, 10) moved to (35, 10) Depth: 69
# Next: (33, 10) moved to (34, 10) Depth: 68
# Next: (33, 9) moved to (33, 10) Depth: 67
# Next: (32, 9) moved to (33, 9) Depth: 66
# Next: (31, 9) moved to (32, 9) Depth: 65
# Next: (30, 9) moved to (31, 9) Depth: 64
# Next: (29, 9) moved to (30, 9) Depth: 63
# Next: (29, 8) moved to (29, 9) Depth: 62
# Next: (28, 8) moved to (29, 8) Depth: 61
# Next: (27, 8) moved to (28, 8) Depth: 60
# Next: (26, 8) moved to (27, 8) Depth: 59
# Next: (25, 8) moved to (26, 8) Depth: 58
# Next: (24, 8) moved to (25, 8) Depth: 57
# Next: (23, 8) moved to (24, 8) Depth: 56
# Next: (22, 8) moved to (23, 8) Depth: 55
# Next: (21, 8) moved to (22, 8) Depth: 54
# Next: (20, 8) moved to (21, 8) Depth: 53
# Next: (19, 8) moved to (20, 8) Depth: 52
# Next: (18, 8) moved to (19, 8) Depth: 51
# Next: (17, 8) moved to (18, 8) Depth: 50
# Next: (16, 8) moved to (17, 8) Depth: 49
# Next: (15, 8) moved to (16, 8) Depth: 48
# Next: (14, 8) moved to (15, 8) Depth: 47
# Next: (14, 7) moved to (14, 8) Depth: 46
# Next: (13, 7) moved to (14, 7) Depth: 45
# Next: (13, 6) moved to (13, 7) Depth: 44
# Next: (12, 6) moved to (13, 6) Depth: 43
# Next: (11, 6) moved to (12, 6) Depth: 42
# Next: (10, 6) moved to (11, 6) Depth: 41
# Next: (9, 6) moved to (10, 6) Depth: 40
# Next: (8, 6) moved to (9, 6) Depth: 39
# Next: (7, 6) moved to (8, 6) Depth: 38
# Next: (6, 6) moved to (7, 6) Depth: 37
# Next: (5, 6) moved to (6, 6) Depth: 36
# Next: (5, 7) moved to (5, 6) Depth: 35
# Next: (4, 7) moved to (5, 7) Depth: 34
# Next: (3, 7) moved to (4, 7) Depth: 33
# Next: (3, 6) moved to (3, 7) Depth: 32
# Next: (2, 6) moved to (3, 6) Depth: 31
# Next: (2, 5) moved to (2, 6) Depth: 30
# Next: (1, 5) moved to (2, 5) Depth: 29
# Next: (0, 5) moved to (1, 5) Depth: 28
# Next: (0, 4) moved to (0, 5) Depth: 27
# Next: (1, 4) moved to (0, 4) Depth: 26
# Next: (2, 4) moved to (1, 4) Depth: 25
# Next: (3, 4) moved to (2, 4) Depth: 24
# Next: (4, 4) moved to (3, 4) Depth: 23
# Next: (5, 4) moved to (4, 4) Depth: 22
# Next: (6, 4) moved to (5, 4) Depth: 21
# Next: (7, 4) moved to (6, 4) Depth: 20
# Next: (8, 4) moved to (7, 4) Depth: 19
# Next: (9, 4) moved to (8, 4) Depth: 18
# Next: (10, 4) moved to (9, 4) Depth: 17
# Next: (11, 4) moved to (10, 4) Depth: 16
# Next: (11, 3) moved to (11, 4) Depth: 15
# Next: (10, 3) moved to (11, 3) Depth: 14
# Next: (9, 3) moved to (10, 3) Depth: 13
# Next: (8, 3) moved to (9, 3) Depth: 12
# Next: (8, 2) moved to (8, 3) Depth: 11
# Next: (7, 2) moved to (8, 2) Depth: 10
# Next: (6, 2) moved to (7, 2) Depth: 9
# Next: (5, 2) moved to (6, 2) Depth: 8
# Next: (5, 1) moved to (5, 2) Depth: 7
# Next: (4, 1) moved to (5, 1) Depth: 6
# Next: (4, 0) moved to (4, 1) Depth: 5
# Next: (3, 0) moved to (4, 0) Depth: 4
# Next: (2, 0) moved to (3, 0) Depth: 3
# Next: (1, 0) moved to (2, 0) Depth: 2
# Start: (0, 0) moved to (1, 0) Depth: 1
# Time taken =  2.43777
#
# Running BFS:
# ERROR: Could not find file <ipython-input-21-217c4ef642fe>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# THIS IS BFS
# Found the End!
# Nodes Expanded: 7958
# Max tree depth searched: 199
# Max frontier size: 294
# Next: (98, 99) moved to (99, 99) Depth: 198
# Next: (97, 99) moved to (98, 99) Depth: 197
# Next: (96, 99) moved to (97, 99) Depth: 196
# Next: (95, 99) moved to (96, 99) Depth: 195
# Next: (94, 99) moved to (95, 99) Depth: 194
# Next: (93, 99) moved to (94, 99) Depth: 193
# Next: (92, 99) moved to (93, 99) Depth: 192
# Next: (91, 99) moved to (92, 99) Depth: 191
# Next: (90, 99) moved to (91, 99) Depth: 190
# Next: (89, 99) moved to (90, 99) Depth: 189
# Next: (88, 99) moved to (89, 99) Depth: 188
# Next: (87, 99) moved to (88, 99) Depth: 187
# Next: (86, 99) moved to (87, 99) Depth: 186
# Next: (85, 99) moved to (86, 99) Depth: 185
# Next: (85, 98) moved to (85, 99) Depth: 184
# Next: (84, 98) moved to (85, 98) Depth: 183
# Next: (83, 98) moved to (84, 98) Depth: 182
# Next: (83, 97) moved to (83, 98) Depth: 181
# Next: (83, 96) moved to (83, 97) Depth: 180
# Next: (82, 96) moved to (83, 96) Depth: 179
# Next: (81, 96) moved to (82, 96) Depth: 178
# Next: (80, 96) moved to (81, 96) Depth: 177
# Next: (79, 96) moved to (80, 96) Depth: 176
# Next: (79, 95) moved to (79, 96) Depth: 175
# Next: (78, 95) moved to (79, 95) Depth: 174
# Next: (77, 95) moved to (78, 95) Depth: 173
# Next: (76, 95) moved to (77, 95) Depth: 172
# Next: (75, 95) moved to (76, 95) Depth: 171
# Next: (74, 95) moved to (75, 95) Depth: 170
# Next: (73, 95) moved to (74, 95) Depth: 169
# Next: (72, 95) moved to (73, 95) Depth: 168
# Next: (71, 95) moved to (72, 95) Depth: 167
# Next: (70, 95) moved to (71, 95) Depth: 166
# Next: (69, 95) moved to (70, 95) Depth: 165
# Next: (68, 95) moved to (69, 95) Depth: 164
# Next: (67, 95) moved to (68, 95) Depth: 163
# Next: (66, 95) moved to (67, 95) Depth: 162
# Next: (65, 95) moved to (66, 95) Depth: 161
# Next: (64, 95) moved to (65, 95) Depth: 160
# Next: (63, 95) moved to (64, 95) Depth: 159
# Next: (62, 95) moved to (63, 95) Depth: 158
# Next: (61, 95) moved to (62, 95) Depth: 157
# Next: (61, 94) moved to (61, 95) Depth: 156
# Next: (61, 93) moved to (61, 94) Depth: 155
# Next: (61, 92) moved to (61, 93) Depth: 154
# Next: (60, 92) moved to (61, 92) Depth: 153
# Next: (59, 92) moved to (60, 92) Depth: 152
# Next: (58, 92) moved to (59, 92) Depth: 151
# Next: (57, 92) moved to (58, 92) Depth: 150
# Next: (56, 92) moved to (57, 92) Depth: 149
# Next: (55, 92) moved to (56, 92) Depth: 148
# Next: (54, 92) moved to (55, 92) Depth: 147
# Next: (53, 92) moved to (54, 92) Depth: 146
# Next: (53, 91) moved to (53, 92) Depth: 145
# Next: (52, 91) moved to (53, 91) Depth: 144
# Next: (51, 91) moved to (52, 91) Depth: 143
# Next: (51, 90) moved to (51, 91) Depth: 142
# Next: (51, 89) moved to (51, 90) Depth: 141
# Next: (50, 89) moved to (51, 89) Depth: 140
# Next: (49, 89) moved to (50, 89) Depth: 139
# Next: (48, 89) moved to (49, 89) Depth: 138
# Next: (47, 89) moved to (48, 89) Depth: 137
# Next: (46, 89) moved to (47, 89) Depth: 136
# Next: (45, 89) moved to (46, 89) Depth: 135
# Next: (44, 89) moved to (45, 89) Depth: 134
# Next: (43, 89) moved to (44, 89) Depth: 133
# Next: (42, 89) moved to (43, 89) Depth: 132
# Next: (42, 88) moved to (42, 89) Depth: 131
# Next: (41, 88) moved to (42, 88) Depth: 130
# Next: (40, 88) moved to (41, 88) Depth: 129
# Next: (39, 88) moved to (40, 88) Depth: 128
# Next: (38, 88) moved to (39, 88) Depth: 127
# Next: (38, 87) moved to (38, 88) Depth: 126
# Next: (38, 86) moved to (38, 87) Depth: 125
# Next: (38, 85) moved to (38, 86) Depth: 124
# Next: (38, 84) moved to (38, 85) Depth: 123
# Next: (37, 84) moved to (38, 84) Depth: 122
# Next: (36, 84) moved to (37, 84) Depth: 121
# Next: (35, 84) moved to (36, 84) Depth: 120
# Next: (35, 83) moved to (35, 84) Depth: 119
# Next: (35, 82) moved to (35, 83) Depth: 118
# Next: (35, 81) moved to (35, 82) Depth: 117
# Next: (35, 80) moved to (35, 81) Depth: 116
# Next: (35, 79) moved to (35, 80) Depth: 115
# Next: (35, 78) moved to (35, 79) Depth: 114
# Next: (34, 78) moved to (35, 78) Depth: 113
# Next: (33, 78) moved to (34, 78) Depth: 112
# Next: (32, 78) moved to (33, 78) Depth: 111
# Next: (32, 77) moved to (32, 78) Depth: 110
# Next: (32, 76) moved to (32, 77) Depth: 109
# Next: (32, 75) moved to (32, 76) Depth: 108
# Next: (32, 74) moved to (32, 75) Depth: 107
# Next: (32, 73) moved to (32, 74) Depth: 106
# Next: (31, 73) moved to (32, 73) Depth: 105
# Next: (30, 73) moved to (31, 73) Depth: 104
# Next: (29, 73) moved to (30, 73) Depth: 103
# Next: (28, 73) moved to (29, 73) Depth: 102
# Next: (27, 73) moved to (28, 73) Depth: 101
# Next: (26, 73) moved to (27, 73) Depth: 100
# Next: (25, 73) moved to (26, 73) Depth: 99
# Next: (25, 72) moved to (25, 73) Depth: 98
# Next: (25, 71) moved to (25, 72) Depth: 97
# Next: (25, 70) moved to (25, 71) Depth: 96
# Next: (25, 69) moved to (25, 70) Depth: 95
# Next: (25, 68) moved to (25, 69) Depth: 94
# Next: (25, 67) moved to (25, 68) Depth: 93
# Next: (25, 66) moved to (25, 67) Depth: 92
# Next: (25, 65) moved to (25, 66) Depth: 91
# Next: (25, 64) moved to (25, 65) Depth: 90
# Next: (25, 63) moved to (25, 64) Depth: 89
# Next: (25, 62) moved to (25, 63) Depth: 88
# Next: (25, 61) moved to (25, 62) Depth: 87
# Next: (25, 60) moved to (25, 61) Depth: 86
# Next: (24, 60) moved to (25, 60) Depth: 85
# Next: (24, 59) moved to (24, 60) Depth: 84
# Next: (23, 59) moved to (24, 59) Depth: 83
# Next: (22, 59) moved to (23, 59) Depth: 82
# Next: (21, 59) moved to (22, 59) Depth: 81
# Next: (21, 58) moved to (21, 59) Depth: 80
# Next: (20, 58) moved to (21, 58) Depth: 79
# Next: (20, 57) moved to (20, 58) Depth: 78
# Next: (20, 56) moved to (20, 57) Depth: 77
# Next: (20, 55) moved to (20, 56) Depth: 76
# Next: (20, 54) moved to (20, 55) Depth: 75
# Next: (20, 53) moved to (20, 54) Depth: 74
# Next: (20, 52) moved to (20, 53) Depth: 73
# Next: (20, 51) moved to (20, 52) Depth: 72
# Next: (20, 50) moved to (20, 51) Depth: 71
# Next: (20, 49) moved to (20, 50) Depth: 70
# Next: (19, 49) moved to (20, 49) Depth: 69
# Next: (19, 48) moved to (19, 49) Depth: 68
# Next: (19, 47) moved to (19, 48) Depth: 67
# Next: (19, 46) moved to (19, 47) Depth: 66
# Next: (19, 45) moved to (19, 46) Depth: 65
# Next: (19, 44) moved to (19, 45) Depth: 64
# Next: (19, 43) moved to (19, 44) Depth: 63
# Next: (18, 43) moved to (19, 43) Depth: 62
# Next: (18, 42) moved to (18, 43) Depth: 61
# Next: (18, 41) moved to (18, 42) Depth: 60
# Next: (18, 40) moved to (18, 41) Depth: 59
# Next: (17, 40) moved to (18, 40) Depth: 58
# Next: (16, 40) moved to (17, 40) Depth: 57
# Next: (15, 40) moved to (16, 40) Depth: 56
# Next: (14, 40) moved to (15, 40) Depth: 55
# Next: (14, 39) moved to (14, 40) Depth: 54
# Next: (14, 38) moved to (14, 39) Depth: 53
# Next: (13, 38) moved to (14, 38) Depth: 52
# Next: (13, 37) moved to (13, 38) Depth: 51
# Next: (13, 36) moved to (13, 37) Depth: 50
# Next: (13, 35) moved to (13, 36) Depth: 49
# Next: (13, 34) moved to (13, 35) Depth: 48
# Next: (12, 34) moved to (13, 34) Depth: 47
# Next: (11, 34) moved to (12, 34) Depth: 46
# Next: (11, 33) moved to (11, 34) Depth: 45
# Next: (11, 32) moved to (11, 33) Depth: 44
# Next: (11, 31) moved to (11, 32) Depth: 43
# Next: (10, 31) moved to (11, 31) Depth: 42
# Next: (9, 31) moved to (10, 31) Depth: 41
# Next: (8, 31) moved to (9, 31) Depth: 40
# Next: (7, 31) moved to (8, 31) Depth: 39
# Next: (6, 31) moved to (7, 31) Depth: 38
# Next: (5, 31) moved to (6, 31) Depth: 37
# Next: (5, 30) moved to (5, 31) Depth: 36
# Next: (5, 29) moved to (5, 30) Depth: 35
# Next: (5, 28) moved to (5, 29) Depth: 34
# Next: (5, 27) moved to (5, 28) Depth: 33
# Next: (5, 26) moved to (5, 27) Depth: 32
# Next: (5, 25) moved to (5, 26) Depth: 31
# Next: (4, 25) moved to (5, 25) Depth: 30
# Next: (3, 25) moved to (4, 25) Depth: 29
# Next: (3, 24) moved to (3, 25) Depth: 28
# Next: (3, 23) moved to (3, 24) Depth: 27
# Next: (3, 22) moved to (3, 23) Depth: 26
# Next: (3, 21) moved to (3, 22) Depth: 25
# Next: (3, 20) moved to (3, 21) Depth: 24
# Next: (3, 19) moved to (3, 20) Depth: 23
# Next: (3, 18) moved to (3, 19) Depth: 22
# Next: (3, 17) moved to (3, 18) Depth: 21
# Next: (3, 16) moved to (3, 17) Depth: 20
# Next: (3, 15) moved to (3, 16) Depth: 19
# Next: (3, 14) moved to (3, 15) Depth: 18
# Next: (3, 13) moved to (3, 14) Depth: 17
# Next: (3, 12) moved to (3, 13) Depth: 16
# Next: (3, 11) moved to (3, 12) Depth: 15
# Next: (3, 10) moved to (3, 11) Depth: 14
# Next: (3, 9) moved to (3, 10) Depth: 13
# Next: (2, 9) moved to (3, 9) Depth: 12
# Next: (1, 9) moved to (2, 9) Depth: 11
# Next: (1, 8) moved to (1, 9) Depth: 10
# Next: (1, 7) moved to (1, 8) Depth: 9
# Next: (1, 6) moved to (1, 7) Depth: 8
# Next: (1, 5) moved to (1, 6) Depth: 7
# Next: (1, 4) moved to (1, 5) Depth: 6
# Next: (1, 3) moved to (1, 4) Depth: 5
# Next: (1, 2) moved to (1, 3) Depth: 4
# Next: (1, 1) moved to (1, 2) Depth: 3
# Next: (1, 0) moved to (1, 1) Depth: 2
# Start: (0, 0) moved to (1, 0) Depth: 1
# Time taken =  4.022947
#
# Running Greedy Best-First Search:
# ERROR: Could not find file <ipython-input-21-217c4ef642fe>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# THIS IS GREEDY Best-First Search
# Found the End!
# Nodes Expanded: 244
# Max tree depth searched: 220
# Max frontier size: 463
# Next: (98, 99) moved to (99, 99) Depth: 220
# Next: (97, 99) moved to (98, 99) Depth: 219
# Next: (96, 99) moved to (97, 99) Depth: 218
# Next: (95, 99) moved to (96, 99) Depth: 217
# Next: (94, 99) moved to (95, 99) Depth: 216
# Next: (93, 99) moved to (94, 99) Depth: 215
# Next: (92, 99) moved to (93, 99) Depth: 214
# Next: (91, 99) moved to (92, 99) Depth: 213
# Next: (90, 99) moved to (91, 99) Depth: 212
# Next: (89, 99) moved to (90, 99) Depth: 211
# Next: (88, 99) moved to (89, 99) Depth: 210
# Next: (87, 99) moved to (88, 99) Depth: 209
# Next: (86, 99) moved to (87, 99) Depth: 208
# Next: (85, 99) moved to (86, 99) Depth: 207
# Next: (85, 98) moved to (85, 99) Depth: 206
# Next: (84, 98) moved to (85, 98) Depth: 205
# Next: (83, 98) moved to (84, 98) Depth: 204
# Next: (83, 99) moved to (83, 98) Depth: 203
# Next: (82, 99) moved to (83, 99) Depth: 202
# Next: (81, 99) moved to (82, 99) Depth: 201
# Next: (80, 99) moved to (81, 99) Depth: 200
# Next: (79, 99) moved to (80, 99) Depth: 199
# Next: (78, 99) moved to (79, 99) Depth: 198
# Next: (77, 99) moved to (78, 99) Depth: 197
# Next: (77, 98) moved to (77, 99) Depth: 196
# Next: (76, 98) moved to (77, 98) Depth: 195
# Next: (75, 98) moved to (76, 98) Depth: 194
# Next: (74, 98) moved to (75, 98) Depth: 193
# Next: (73, 98) moved to (74, 98) Depth: 192
# Next: (72, 98) moved to (73, 98) Depth: 191
# Next: (71, 98) moved to (72, 98) Depth: 190
# Next: (70, 98) moved to (71, 98) Depth: 189
# Next: (70, 97) moved to (70, 98) Depth: 188
# Next: (69, 97) moved to (70, 97) Depth: 187
# Next: (69, 96) moved to (69, 97) Depth: 186
# Next: (69, 95) moved to (69, 96) Depth: 185
# Next: (68, 95) moved to (69, 95) Depth: 184
# Next: (67, 95) moved to (68, 95) Depth: 183
# Next: (66, 95) moved to (67, 95) Depth: 182
# Next: (65, 95) moved to (66, 95) Depth: 181
# Next: (65, 96) moved to (65, 95) Depth: 180
# Next: (64, 96) moved to (65, 96) Depth: 179
# Next: (64, 97) moved to (64, 96) Depth: 178
# Next: (64, 98) moved to (64, 97) Depth: 177
# Next: (63, 98) moved to (64, 98) Depth: 176
# Next: (62, 98) moved to (63, 98) Depth: 175
# Next: (62, 99) moved to (62, 98) Depth: 174
# Next: (61, 99) moved to (62, 99) Depth: 173
# Next: (60, 99) moved to (61, 99) Depth: 172
# Next: (59, 99) moved to (60, 99) Depth: 171
# Next: (58, 99) moved to (59, 99) Depth: 170
# Next: (58, 98) moved to (58, 99) Depth: 169
# Next: (57, 98) moved to (58, 98) Depth: 168
# Next: (56, 98) moved to (57, 98) Depth: 167
# Next: (56, 99) moved to (56, 98) Depth: 166
# Next: (55, 99) moved to (56, 99) Depth: 165
# Next: (54, 99) moved to (55, 99) Depth: 164
# Next: (53, 99) moved to (54, 99) Depth: 163
# Next: (53, 98) moved to (53, 99) Depth: 162
# Next: (52, 98) moved to (53, 98) Depth: 161
# Next: (52, 97) moved to (52, 98) Depth: 160
# Next: (51, 97) moved to (52, 97) Depth: 159
# Next: (50, 97) moved to (51, 97) Depth: 158
# Next: (49, 97) moved to (50, 97) Depth: 157
# Next: (48, 97) moved to (49, 97) Depth: 156
# Next: (48, 98) moved to (48, 97) Depth: 155
# Next: (48, 99) moved to (48, 98) Depth: 154
# Next: (47, 99) moved to (48, 99) Depth: 153
# Next: (46, 99) moved to (47, 99) Depth: 152
# Next: (46, 98) moved to (46, 99) Depth: 151
# Next: (45, 98) moved to (46, 98) Depth: 150
# Next: (44, 98) moved to (45, 98) Depth: 149
# Next: (43, 98) moved to (44, 98) Depth: 148
# Next: (43, 97) moved to (43, 98) Depth: 147
# Next: (42, 97) moved to (43, 97) Depth: 146
# Next: (41, 97) moved to (42, 97) Depth: 145
# Next: (41, 96) moved to (41, 97) Depth: 144
# Next: (41, 95) moved to (41, 96) Depth: 143
# Next: (41, 94) moved to (41, 95) Depth: 142
# Next: (40, 94) moved to (41, 94) Depth: 141
# Next: (39, 94) moved to (40, 94) Depth: 140
# Next: (38, 94) moved to (39, 94) Depth: 139
# Next: (38, 93) moved to (38, 94) Depth: 138
# Next: (38, 92) moved to (38, 93) Depth: 137
# Next: (38, 91) moved to (38, 92) Depth: 136
# Next: (38, 90) moved to (38, 91) Depth: 135
# Next: (38, 89) moved to (38, 90) Depth: 134
# Next: (38, 88) moved to (38, 89) Depth: 133
# Next: (38, 87) moved to (38, 88) Depth: 132
# Next: (38, 86) moved to (38, 87) Depth: 131
# Next: (38, 85) moved to (38, 86) Depth: 130
# Next: (38, 84) moved to (38, 85) Depth: 129
# Next: (37, 84) moved to (38, 84) Depth: 128
# Next: (36, 84) moved to (37, 84) Depth: 127
# Next: (35, 84) moved to (36, 84) Depth: 126
# Next: (35, 83) moved to (35, 84) Depth: 125
# Next: (35, 82) moved to (35, 83) Depth: 124
# Next: (35, 81) moved to (35, 82) Depth: 123
# Next: (35, 80) moved to (35, 81) Depth: 122
# Next: (35, 79) moved to (35, 80) Depth: 121
# Next: (35, 78) moved to (35, 79) Depth: 120
# Next: (34, 78) moved to (35, 78) Depth: 119
# Next: (33, 78) moved to (34, 78) Depth: 118
# Next: (32, 78) moved to (33, 78) Depth: 117
# Next: (32, 77) moved to (32, 78) Depth: 116
# Next: (32, 76) moved to (32, 77) Depth: 115
# Next: (32, 75) moved to (32, 76) Depth: 114
# Next: (32, 74) moved to (32, 75) Depth: 113
# Next: (32, 73) moved to (32, 74) Depth: 112
# Next: (31, 73) moved to (32, 73) Depth: 111
# Next: (30, 73) moved to (31, 73) Depth: 110
# Next: (30, 74) moved to (30, 73) Depth: 109
# Next: (29, 74) moved to (30, 74) Depth: 108
# Next: (28, 74) moved to (29, 74) Depth: 107
# Next: (27, 74) moved to (28, 74) Depth: 106
# Next: (26, 74) moved to (27, 74) Depth: 105
# Next: (25, 74) moved to (26, 74) Depth: 104
# Next: (25, 73) moved to (25, 74) Depth: 103
# Next: (25, 72) moved to (25, 73) Depth: 102
# Next: (25, 71) moved to (25, 72) Depth: 101
# Next: (25, 70) moved to (25, 71) Depth: 100
# Next: (25, 69) moved to (25, 70) Depth: 99
# Next: (25, 68) moved to (25, 69) Depth: 98
# Next: (25, 67) moved to (25, 68) Depth: 97
# Next: (25, 66) moved to (25, 67) Depth: 96
# Next: (25, 65) moved to (25, 66) Depth: 95
# Next: (25, 64) moved to (25, 65) Depth: 94
# Next: (25, 63) moved to (25, 64) Depth: 93
# Next: (25, 62) moved to (25, 63) Depth: 92
# Next: (25, 61) moved to (25, 62) Depth: 91
# Next: (25, 60) moved to (25, 61) Depth: 90
# Next: (24, 60) moved to (25, 60) Depth: 89
# Next: (24, 59) moved to (24, 60) Depth: 88
# Next: (23, 59) moved to (24, 59) Depth: 87
# Next: (22, 59) moved to (23, 59) Depth: 86
# Next: (21, 59) moved to (22, 59) Depth: 85
# Next: (21, 58) moved to (21, 59) Depth: 84
# Next: (20, 58) moved to (21, 58) Depth: 83
# Next: (20, 57) moved to (20, 58) Depth: 82
# Next: (20, 56) moved to (20, 57) Depth: 81
# Next: (20, 55) moved to (20, 56) Depth: 80
# Next: (20, 54) moved to (20, 55) Depth: 79
# Next: (20, 53) moved to (20, 54) Depth: 78
# Next: (20, 52) moved to (20, 53) Depth: 77
# Next: (20, 51) moved to (20, 52) Depth: 76
# Next: (20, 50) moved to (20, 51) Depth: 75
# Next: (20, 49) moved to (20, 50) Depth: 74
# Next: (19, 49) moved to (20, 49) Depth: 73
# Next: (19, 48) moved to (19, 49) Depth: 72
# Next: (19, 47) moved to (19, 48) Depth: 71
# Next: (19, 46) moved to (19, 47) Depth: 70
# Next: (19, 45) moved to (19, 46) Depth: 69
# Next: (19, 44) moved to (19, 45) Depth: 68
# Next: (19, 43) moved to (19, 44) Depth: 67
# Next: (18, 43) moved to (19, 43) Depth: 66
# Next: (18, 42) moved to (18, 43) Depth: 65
# Next: (18, 41) moved to (18, 42) Depth: 64
# Next: (18, 40) moved to (18, 41) Depth: 63
# Next: (17, 40) moved to (18, 40) Depth: 62
# Next: (16, 40) moved to (17, 40) Depth: 61
# Next: (15, 40) moved to (16, 40) Depth: 60
# Next: (14, 40) moved to (15, 40) Depth: 59
# Next: (14, 39) moved to (14, 40) Depth: 58
# Next: (14, 38) moved to (14, 39) Depth: 57
# Next: (13, 38) moved to (14, 38) Depth: 56
# Next: (13, 37) moved to (13, 38) Depth: 55
# Next: (13, 36) moved to (13, 37) Depth: 54
# Next: (13, 35) moved to (13, 36) Depth: 53
# Next: (13, 34) moved to (13, 35) Depth: 52
# Next: (12, 34) moved to (13, 34) Depth: 51
# Next: (11, 34) moved to (12, 34) Depth: 50
# Next: (11, 33) moved to (11, 34) Depth: 49
# Next: (11, 32) moved to (11, 33) Depth: 48
# Next: (11, 31) moved to (11, 32) Depth: 47
# Next: (10, 31) moved to (11, 31) Depth: 46
# Next: (9, 31) moved to (10, 31) Depth: 45
# Next: (8, 31) moved to (9, 31) Depth: 44
# Next: (7, 31) moved to (8, 31) Depth: 43
# Next: (7, 32) moved to (7, 31) Depth: 42
# Next: (7, 33) moved to (7, 32) Depth: 41
# Next: (6, 33) moved to (7, 33) Depth: 40
# Next: (5, 33) moved to (6, 33) Depth: 39
# Next: (5, 32) moved to (5, 33) Depth: 38
# Next: (5, 31) moved to (5, 32) Depth: 37
# Next: (5, 30) moved to (5, 31) Depth: 36
# Next: (5, 29) moved to (5, 30) Depth: 35
# Next: (5, 28) moved to (5, 29) Depth: 34
# Next: (5, 27) moved to (5, 28) Depth: 33
# Next: (5, 26) moved to (5, 27) Depth: 32
# Next: (5, 25) moved to (5, 26) Depth: 31
# Next: (4, 25) moved to (5, 25) Depth: 30
# Next: (3, 25) moved to (4, 25) Depth: 29
# Next: (3, 24) moved to (3, 25) Depth: 28
# Next: (3, 23) moved to (3, 24) Depth: 27
# Next: (3, 22) moved to (3, 23) Depth: 26
# Next: (3, 21) moved to (3, 22) Depth: 25
# Next: (3, 20) moved to (3, 21) Depth: 24
# Next: (3, 19) moved to (3, 20) Depth: 23
# Next: (3, 18) moved to (3, 19) Depth: 22
# Next: (3, 17) moved to (3, 18) Depth: 21
# Next: (3, 16) moved to (3, 17) Depth: 20
# Next: (3, 15) moved to (3, 16) Depth: 19
# ...
# Next: (91, 56) moved to (91, 57) Depth: 200
# Next: (91, 55) moved to (91, 56) Depth: 199
# Next: (92, 55) moved to (91, 55) Depth: 198
# Next: (92, 54) moved to (92, 55) Depth: 197
# Next: (93, 54) moved to (92, 54) Depth: 196
# Next: (94, 54) moved to (93, 54) Depth: 195
# Next: (94, 53) moved to (94, 54) Depth: 194
# Next: (95, 53) moved to (94, 53) Depth: 193
# Next: (95, 52) moved to (95, 53) Depth: 192
# Next: (95, 51) moved to (95, 52) Depth: 191
# Next: (96, 51) moved to (95, 51) Depth: 190
# Next: (97, 51) moved to (96, 51) Depth: 189
# Next: (97, 50) moved to (97, 51) Depth: 188
# Next: (97, 49) moved to (97, 50) Depth: 187
# Next: (97, 48) moved to (97, 49) Depth: 186
# Next: (98, 48) moved to (97, 48) Depth: 185
# Next: (98, 47) moved to (98, 48) Depth: 184
# Next: (99, 47) moved to (98, 47) Depth: 183
# Next: (99, 46) moved to (99, 47) Depth: 182
# Next: (99, 45) moved to (99, 46) Depth: 181
# Next: (99, 44) moved to (99, 45) Depth: 180
# Next: (98, 44) moved to (99, 44) Depth: 179
# Next: (97, 44) moved to (98, 44) Depth: 178
# Next: (96, 44) moved to (97, 44) Depth: 177
# Next: (96, 43) moved to (96, 44) Depth: 176
# Next: (95, 43) moved to (96, 43) Depth: 175
# Next: (94, 43) moved to (95, 43) Depth: 174
# Next: (94, 42) moved to (94, 43) Depth: 173
# Next: (93, 42) moved to (94, 42) Depth: 172
# Next: (92, 42) moved to (93, 42) Depth: 171
# Next: (92, 41) moved to (92, 42) Depth: 170
# Next: (92, 40) moved to (92, 41) Depth: 169
# Next: (92, 39) moved to (92, 40) Depth: 168
# Next: (93, 39) moved to (92, 39) Depth: 167
# Next: (93, 38) moved to (93, 39) Depth: 166
# Next: (93, 37) moved to (93, 38) Depth: 165
# Next: (93, 36) moved to (93, 37) Depth: 164
# Next: (93, 35) moved to (93, 36) Depth: 163
# Next: (92, 35) moved to (93, 35) Depth: 162
# Next: (91, 35) moved to (92, 35) Depth: 161
# Next: (90, 35) moved to (91, 35) Depth: 160
# Next: (90, 34) moved to (90, 35) Depth: 159
# Next: (91, 34) moved to (90, 34) Depth: 158
# Next: (91, 33) moved to (91, 34) Depth: 157
# Next: (91, 32) moved to (91, 33) Depth: 156
# Next: (92, 32) moved to (91, 32) Depth: 155
# Next: (93, 32) moved to (92, 32) Depth: 154
# Next: (94, 32) moved to (93, 32) Depth: 153
# Next: (94, 31) moved to (94, 32) Depth: 152
# Next: (94, 30) moved to (94, 31) Depth: 151
# Next: (94, 29) moved to (94, 30) Depth: 150
# Next: (94, 28) moved to (94, 29) Depth: 149
# Next: (93, 28) moved to (94, 28) Depth: 148
# Next: (92, 28) moved to (93, 28) Depth: 147
# Next: (91, 28) moved to (92, 28) Depth: 146
# Next: (91, 27) moved to (91, 28) Depth: 145
# Next: (90, 27) moved to (91, 27) Depth: 144
# Next: (90, 26) moved to (90, 27) Depth: 143
# Next: (90, 25) moved to (90, 26) Depth: 142
# Next: (91, 25) moved to (90, 25) Depth: 141
# Next: (91, 24) moved to (91, 25) Depth: 140
# Next: (91, 23) moved to (91, 24) Depth: 139
# Next: (91, 22) moved to (91, 23) Depth: 138
# Next: (92, 22) moved to (91, 22) Depth: 137
# Next: (92, 21) moved to (92, 22) Depth: 136
# Next: (92, 20) moved to (92, 21) Depth: 135
# Next: (93, 20) moved to (92, 20) Depth: 134
# Next: (94, 20) moved to (93, 20) Depth: 133
# Next: (95, 20) moved to (94, 20) Depth: 132
# Next: (95, 19) moved to (95, 20) Depth: 131
# Next: (95, 18) moved to (95, 19) Depth: 130
# Next: (96, 18) moved to (95, 18) Depth: 129
# Next: (97, 18) moved to (96, 18) Depth: 128
# Next: (97, 17) moved to (97, 18) Depth: 127
# Next: (97, 16) moved to (97, 17) Depth: 126
# Next: (97, 15) moved to (97, 16) Depth: 125
# Next: (98, 15) moved to (97, 15) Depth: 124
# Next: (98, 14) moved to (98, 15) Depth: 123
# Next: (99, 14) moved to (98, 14) Depth: 122
# Next: (99, 13) moved to (99, 14) Depth: 121
# Next: (99, 12) moved to (99, 13) Depth: 120
# Next: (99, 11) moved to (99, 12) Depth: 119
# Next: (98, 11) moved to (99, 11) Depth: 118
# Next: (97, 11) moved to (98, 11) Depth: 117
# Next: (96, 11) moved to (97, 11) Depth: 116
# Next: (96, 10) moved to (96, 11) Depth: 115
# Next: (95, 10) moved to (96, 10) Depth: 114
# Next: (94, 10) moved to (95, 10) Depth: 113
# Next: (93, 10) moved to (94, 10) Depth: 112
# Next: (92, 10) moved to (93, 10) Depth: 111
# Next: (91, 10) moved to (92, 10) Depth: 110
# Next: (90, 10) moved to (91, 10) Depth: 109
# Next: (90, 9) moved to (90, 10) Depth: 108
# Next: (89, 9) moved to (90, 9) Depth: 107
# Next: (88, 9) moved to (89, 9) Depth: 106
# Next: (87, 9) moved to (88, 9) Depth: 105
# Next: (86, 9) moved to (87, 9) Depth: 104
# Next: (85, 9) moved to (86, 9) Depth: 103
# Next: (84, 9) moved to (85, 9) Depth: 102
# Next: (83, 9) moved to (84, 9) Depth: 101
# Next: (82, 9) moved to (83, 9) Depth: 100
# Next: (81, 9) moved to (82, 9) Depth: 99
# Next: (80, 9) moved to (81, 9) Depth: 98
# Next: (79, 9) moved to (80, 9) Depth: 97
# Next: (78, 9) moved to (79, 9) Depth: 96
# Next: (77, 9) moved to (78, 9) Depth: 95
# Next: (76, 9) moved to (77, 9) Depth: 94
# Next: (75, 9) moved to (76, 9) Depth: 93
# Next: (74, 9) moved to (75, 9) Depth: 92
# Next: (74, 10) moved to (74, 9) Depth: 91
# Next: (73, 10) moved to (74, 10) Depth: 90
# Next: (72, 10) moved to (73, 10) Depth: 89
# Next: (71, 10) moved to (72, 10) Depth: 88
# Next: (71, 11) moved to (71, 10) Depth: 87
# Next: (70, 11) moved to (71, 11) Depth: 86
# Next: (69, 11) moved to (70, 11) Depth: 85
# Next: (68, 11) moved to (69, 11) Depth: 84
# Next: (67, 11) moved to (68, 11) Depth: 83
# Next: (66, 11) moved to (67, 11) Depth: 82
# Next: (65, 11) moved to (66, 11) Depth: 81
# Next: (64, 11) moved to (65, 11) Depth: 80
# Next: (64, 12) moved to (64, 11) Depth: 79
# Next: (63, 12) moved to (64, 12) Depth: 78
# Next: (62, 12) moved to (63, 12) Depth: 77
# Next: (61, 12) moved to (62, 12) Depth: 76
# Next: (60, 12) moved to (61, 12) Depth: 75
# Next: (59, 12) moved to (60, 12) Depth: 74
# Next: (58, 12) moved to (59, 12) Depth: 73
# Next: (57, 12) moved to (58, 12) Depth: 72
# Next: (56, 12) moved to (57, 12) Depth: 71
# Next: (55, 12) moved to (56, 12) Depth: 70
# Next: (54, 12) moved to (55, 12) Depth: 69
# Next: (54, 11) moved to (54, 12) Depth: 68
# Next: (53, 11) moved to (54, 11) Depth: 67
# Next: (52, 11) moved to (53, 11) Depth: 66
# Next: (51, 11) moved to (52, 11) Depth: 65
# Next: (51, 10) moved to (51, 11) Depth: 64
# Next: (51, 9) moved to (51, 10) Depth: 63
# Next: (51, 8) moved to (51, 9) Depth: 62
# Next: (50, 8) moved to (51, 8) Depth: 61
# Next: (49, 8) moved to (50, 8) Depth: 60
# Next: (48, 8) moved to (49, 8) Depth: 59
# Next: (47, 8) moved to (48, 8) Depth: 58
# Next: (47, 7) moved to (47, 8) Depth: 57
# Next: (47, 6) moved to (47, 7) Depth: 56
# Next: (46, 6) moved to (47, 6) Depth: 55
# Next: (45, 6) moved to (46, 6) Depth: 54
# Next: (44, 6) moved to (45, 6) Depth: 53
# Next: (43, 6) moved to (44, 6) Depth: 52
# Next: (43, 5) moved to (43, 6) Depth: 51
# Next: (43, 4) moved to (43, 5) Depth: 50
# Next: (42, 4) moved to (43, 4) Depth: 49
# Next: (41, 4) moved to (42, 4) Depth: 48
# Next: (40, 4) moved to (41, 4) Depth: 47
# Next: (39, 4) moved to (40, 4) Depth: 46
# Next: (38, 4) moved to (39, 4) Depth: 45
# Next: (37, 4) moved to (38, 4) Depth: 44
# Next: (36, 4) moved to (37, 4) Depth: 43
# Next: (35, 4) moved to (36, 4) Depth: 42
# Next: (34, 4) moved to (35, 4) Depth: 41
# Next: (33, 4) moved to (34, 4) Depth: 40
# Next: (32, 4) moved to (33, 4) Depth: 39
# Next: (31, 4) moved to (32, 4) Depth: 38
# Next: (30, 4) moved to (31, 4) Depth: 37
# Next: (29, 4) moved to (30, 4) Depth: 36
# Next: (28, 4) moved to (29, 4) Depth: 35
# Next: (27, 4) moved to (28, 4) Depth: 34
# Next: (26, 4) moved to (27, 4) Depth: 33
# Next: (25, 4) moved to (26, 4) Depth: 32
# Next: (24, 4) moved to (25, 4) Depth: 31
# Next: (23, 4) moved to (24, 4) Depth: 30
# Next: (22, 4) moved to (23, 4) Depth: 29
# Next: (21, 4) moved to (22, 4) Depth: 28
# Next: (20, 4) moved to (21, 4) Depth: 27
# Next: (19, 4) moved to (20, 4) Depth: 26
# Next: (18, 4) moved to (19, 4) Depth: 25
# Next: (17, 4) moved to (18, 4) Depth: 24
# Next: (16, 4) moved to (17, 4) Depth: 23
# Next: (16, 5) moved to (16, 4) Depth: 22
# Next: (15, 5) moved to (16, 5) Depth: 21
# Next: (14, 5) moved to (15, 5) Depth: 20
# Next: (13, 5) moved to (14, 5) Depth: 19
# Next: (12, 5) moved to (13, 5) Depth: 18
# Next: (11, 5) moved to (12, 5) Depth: 17
# Next: (11, 4) moved to (11, 5) Depth: 16
# Next: (10, 4) moved to (11, 4) Depth: 15
# Next: (9, 4) moved to (10, 4) Depth: 14
# Next: (8, 4) moved to (9, 4) Depth: 13
# Next: (8, 3) moved to (8, 4) Depth: 12
# Next: (7, 3) moved to (8, 3) Depth: 11
# Next: (6, 3) moved to (7, 3) Depth: 10
# Next: (6, 2) moved to (6, 3) Depth: 9
# Next: (5, 2) moved to (6, 2) Depth: 8
# Next: (5, 1) moved to (5, 2) Depth: 7
# Next: (4, 1) moved to (5, 1) Depth: 6
# Next: (3, 1) moved to (4, 1) Depth: 5
# Next: (2, 1) moved to (3, 1) Depth: 4
# Next: (1, 1) moved to (2, 1) Depth: 3
# Next: (1, 0) moved to (1, 1) Depth: 2
# Start: (0, 0) moved to (1, 0) Depth: 1
# Time taken =  0.770633
#
# Running Hill Climbing Search:
# ERROR: Could not find file <ipython-input-21-217c4ef642fe>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# THIS IS Hill Climbing Search
# Reached a local maximum, search stopped.
# None
# Time taken =  0.003975
#
# Running Genetic Algorithm:
# Generation 0: Best Fitness = 10454
# Generation 100: Best Fitness = 10454
# Generation 200: Best Fitness = 10454
# Generation 300: Best Fitness = 10454
# Generation 400: Best Fitness = 10454
# Generation 500: Best Fitness = 10454
# Generation 600: Best Fitness = 10454
# Generation 700: Best Fitness = 10454
# Generation 800: Best Fitness = 10454
# Generation 900: Best Fitness = 10454
# Best path found: ['down', 'right', 'down', 'right', 'left', 'right', 'left', 'right', 'right', 'left', 'left', 'up', 'right', 'right', 'up', 'left', 'right', 'right', 'down', 'up', 'left', 'right', 'left', 'down', 'left', 'right', 'up', 'down', 'left', 'up', 'down', 'right', 'down', 'up', 'down', 'up', 'up', 'left', 'down', 'right', 'right', 'down', 'up', 'down', 'right', 'left', 'right', 'right', 'up', 'up', 'down', 'left', 'left', 'down', 'left', 'up', 'right', 'up', 'right', 'down', 'left', 'right', 'down', 'left', 'down', 'down', 'right', 'left', 'left', 'right', 'right', 'left', 'up', 'down', 'right', 'left', 'down', 'left', 'down', 'left', 'down', 'down', 'right', 'down', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'left', 'down', 'down', 'right', 'up', 'down', 'up', 'right', 'left', 'up', 'down', 'down', 'right', 'left', 'down', 'right', 'down', 'right', 'down', 'up', 'left', 'up', 'right', 'right', 'down', 'left', 'left', 'up', 'down', 'up', 'right', 'left', 'right', 'left', 'right', 'up', 'right', 'right', 'left', 'down', 'left', 'down', 'down', 'right', 'left', 'right', 'down', 'right', 'up', 'up', 'down', 'left', 'right', 'left', 'left', 'up', 'down', 'right', 'right', 'right', 'right', 'right', 'left', 'right', 'left', 'up', 'down', 'down', 'right', 'left', 'left', 'down', 'left', 'down', 'right', 'right', 'down', 'right', 'up', 'left', 'left', 'down', 'down', 'down', 'up', 'down', 'down', 'right', 'right', 'down', 'up', 'right', 'down', 'up', 'left', 'left', 'left', 'left', 'up', 'right', 'left', 'down', 'right', 'right', 'left', 'right', 'right', 'down', 'right', 'left', 'up', 'left', 'left', 'up', 'left', 'right', 'left', 'down', 'up', 'down', 'right', 'down', 'left', 'up', 'up', 'down', 'left', 'left', 'left', 'left', 'down', 'left', 'right', 'up', 'right', 'up', 'up', 'down', 'left', 'right', 'down', 'up', 'left', 'left', 'right', 'left', 'left', 'up', 'left', 'down', 'down', 'up', 'down', 'down', 'down', 'up', 'down', 'down', 'up', 'down', 'up', 'right', 'down', 'up', 'right', 'left', 'left', 'right', 'down', 'left', 'down', 'up', 'down', 'up', 'down', 'up', 'right', 'right', 'left', 'right', 'left', 'left', 'down', 'up', 'down', 'up', 'right', 'up', 'down', 'right', 'right', 'right', 'left', 'right', 'right', 'right', 'right', 'up', 'right', 'up', 'left', 'down', 'left', 'right', 'up', 'up', 'left', 'right', 'left', 'right', 'right', 'down', 'up', 'left', 'down', 'right', 'up', 'up', 'down', 'up', 'down', 'up', 'up', 'down', 'down', 'right', 'right', 'left', 'left', 'up', 'down', 'left', 'left', 'right', 'right', 'left', 'left', 'left', 'right', 'right', 'up', 'right', 'up', 'down', 'down', 'up', 'down', 'up', 'left', 'down', 'left', 'left', 'left', 'down', 'left', 'up', 'down', 'up', 'right', 'right', 'down', 'left', 'left', 'up', 'right', 'up', 'left', 'down', 'right', 'up', 'down', 'left', 'right', 'down', 'right', 'down', 'left', 'down', 'up', 'left', 'down', 'left', 'right', 'up', 'down', 'up', 'down', 'left', 'left', 'left', 'up', 'down', 'down', 'up', 'right', 'right', 'left', 'left', 'right', 'up', 'up', 'down', 'right', 'left', 'down', 'up', 'up', 'up', 'down', 'left', 'right', 'right', 'right', 'down', 'left', 'up', 'down', 'down', 'left', 'right', 'left', 'left', 'right', 'left', 'down', 'up', 'down', 'up', 'up', 'down', 'up', 'down', 'up', 'up', 'down', 'down', 'down', 'up', 'down', 'up', 'up', 'right', 'up', 'down', 'up', 'right', 'down', 'down', 'right', 'down', 'right', 'right', 'right', 'down', 'down', 'right', 'left', 'down', 'down', 'left', 'down', 'up', 'up', 'down', 'right', 'down', 'right', 'right', 'up', 'up', 'left', 'down', 'left', 'left', 'right', 'right', 'down', 'right', 'left', 'left', 'left', 'down', 'left', 'down', 'left', 'down', 'down', 'down', 'down', 'left', 'up', 'right', 'left', 'down', 'down', 'left', 'left', 'up', 'up', 'right', 'right', 'left', 'left', 'down', 'up', 'right', 'down', 'down', 'right', 'left', 'right', 'down', 'up', 'up', 'up', 'right', 'down', 'right',  ...
# Fitness: 10454
# Time taken =  65.400102
#
# Running IDS:
# ERROR: Could not find file <ipython-input-21-217c4ef642fe>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
# THIS IS IDS
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-26-ee2906d30f37> in <cell line: 1>()
#      70     maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
#      71     #start_time = time.time()
# ---> 72     IDSpath=Running_IDS(maze)
#      73     #end_time = time.time()
#      74     #print("Time taken = ",round(end_time - start_time,6))
#
# /usr/local/lib/python3.10/dist-packages/memory_profiler.py in wrapper(*args, **kwargs)
#    1186             def wrapper(*args, **kwargs):
#    1187                 prof = get_prof()
# -> 1188                 val = prof(func)(*args, **kwargs)
#    1189                 show_results_bound(prof)
#    1190                 return val
#
# /usr/local/lib/python3.10/dist-packages/memory_profiler.py in f(*args, **kwds)
#     759             def f(*args, **kwds):
#     760                 with self._count_ctxmgr():
# --> 761                     return func(*args, **kwds)
#     762
#     763         return f
#
# <ipython-input-21-217c4ef642fe> in Running_IDS(maze)
#      25 @profile
#      26 def Running_IDS(maze):
# ---> 27     return ids(maze)
#      28
#      29 @profile
#
# <ipython-input-20-23aa2fcd1dc4> in ids(maze)
#       7         solutions = []
#       8         start = Pair(maze.startX, maze.startY, -1, -1, 0)
# ----> 9         if dls(maze, start, depth, solutions):
#      10             print("Found the End!")
#      11             print(f"Max depth limit: {depth}")
#
# <ipython-input-17-bb36bb171779> in dls(maze, curr, depth, solutions)
#      15                 dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
#      16                 temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
# ---> 17                 if dls(maze, temp, depth - 1, solutions):
#      18                     return True
#      19         solutions.pop()  # Backtrack
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-17-bb36bb171779> in dls(maze, curr, depth, solutions)
#      15                 dx, dy = {"up": (0, -1), "down": (0, 1), "left": (-1, 0), "right": (1, 0)}[direction]
#      16                 temp = Pair(curr.first + dx, curr.second + dy, curr.first, curr.second, curr.depth + 1)
# ---> 17                 if dls(maze, temp, depth - 1, solutions):
#      18                     return True
#      19         solutions.pop()  # Backtrack
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# ###Shorter version

# %%
''' def run_search(maze, search_name, search_function):
    print(f"\nRunning {search_name}:")
    maze.visited = [[False for _ in row] for row in maze.maze]  # Reset visited
    start_time = time.time()
    path = search_function(maze)
    end_time = time.time()
    print(f"Time taken = {round(end_time - start_time, 6)}")
    if path is not None:
        print(path)  # print into terminal
    return path

BFS_path = run_search(maze, "BFS", Running_BFS)
Greedy_path = run_search(maze, "Greedy Best-First Search", Running_Greedy)
A_star_path = run_search(maze, "A* Search", Running_A_Star)
UCS_path = run_search(maze, "Uniform Cost Search", Running_UCS)
IDS_path = run_search(maze, "IDS", Running_IDS)
hillpath = run_search(maze, "Hill Climbing Search", Running_Hill_Climbing)
 '''
